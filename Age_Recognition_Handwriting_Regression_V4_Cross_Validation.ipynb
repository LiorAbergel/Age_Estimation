# %% [markdown]
# # Imports

# %%
# System and OS utilities
import os, math, itertools, warnings, gc
from collections import defaultdict
from google.colab import drive
from os.path import join

# Data manipulation and processing
import numpy as np
import pandas as pd

# TensorFlow and Keras
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import (
    Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Input, GlobalAveragePooling2D
)
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.applications import (
    ResNet50, EfficientNetB0, InceptionV3, InceptionResNetV2, DenseNet121
)
from tensorflow.keras.applications.efficientnet_v2 import EfficientNetV2M

# Scikit-learn for data preprocessing and splitting
from sklearn.model_selection import train_test_split, StratifiedGroupKFold
from sklearn.preprocessing import MinMaxScaler

# Image processing
from PIL import Image

# Utility libraries
from tqdm import tqdm

import matplotlib.pyplot as plt

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
drive.mount('/content/drive')

# Load the images
DATA_ROOT = '/content/drive/MyDrive/Expanded_HHD_AgeSplit'

# Load the CSV file
csv_dir = os.path.join(DATA_ROOT, 'NewAgeSplit.csv')
labels_data = pd.read_csv(csv_dir)
# Out:
# Mounted at /content/drive

# %%
BATCH_SIZE = 64

# %% [markdown]
# # Training

# %% [markdown]
# ## Loading Images and Preprocessing

# %%
def calculate_resized_dimensions(height, width, patch_size=400, stride=200, standard_size=800):
    """
    Calculates resized dimensions to maintain aspect ratio, be compatible with patching, and close to a standard size.

    Args:
        height (int): Original height of the image.
        width (int): Original width of the image.
        patch_size (int): Size of each patch (default 400).
        stride (int): Stride for patching (default 200).
        standard_size (int): Target standard size for the smaller dimension.

    Returns:
        tuple: Resized height and width.
    """
    aspect_ratio = width / height

    # Scale dimensions such that the smaller side matches the standard size
    if height < width:
        new_height = standard_size
        new_width = int(new_height * aspect_ratio)
    else:
        new_width = standard_size
        new_height = int(new_width / aspect_ratio)

    # Adjust dimensions to be compatible with patching
    def adjust_dimension(dim):
        remainder = (dim - patch_size) % stride
        return dim if remainder == 0 else dim - remainder

    new_height = adjust_dimension(new_height)
    new_width = adjust_dimension(new_width)

    return new_height, new_width

# %%
def read_tiff_image_with_dynamic_resize(img_path):
    """
    Reads a TIFF image, dynamically resizes it to be compatible with patches and standard size, and normalizes it.

    Args:
        img_path (tf.Tensor): Path to the image file.

    Returns:
        np.ndarray: Resized and normalized image as a NumPy array.
    """
    img = Image.open(img_path.numpy().decode("utf-8"))  # Load TIFF file
    img = img.convert('RGB')  # Convert to RGB if necessary
    original_size = img.size  # Original dimensions (width, height)
    new_height, new_width = calculate_resized_dimensions(original_size[1], original_size[0])
    img = img.resize((new_width, new_height), Image.Resampling.LANCZOS)  # Resize dynamically with LANCZOS
    img_array = np.array(img, dtype=np.float32) / 255.0  # Normalize pixel values
    return img_array

# %%
def process_image(row, root_dir, patch_size, step_size):
    """
    Processes a row to load the corresponding image, extract patches, and assign labels.

    Args:
        row (dict): Dictionary containing file path and label data.
        data_dir (str): Directory containing the images.
        patch_size (tuple): Size of each patch (height, width).
        step_size (int): Step size for extracting patches.

    Returns:
        tuple: Patches and corresponding labels.
    """
   # 1) turn the Python string into a tf.string scalar
    root = tf.constant(root_dir, dtype=tf.string)

    # 2) these are SymbolicTensors of dtype tf.string
    subset = row['Set']   # e.g. b'train'
    fname  = row['File']  # e.g. b'img123.tif'

    # 3) join them with TF ops, not os.path
    #    result is a tf.Tensor of dtype string like b'/…/HHD_AgeSplit/train/img123.tif'
    img_path = tf.strings.join([root, subset, fname], separator=os.path.sep)

    # 4) load & resize via py_function
    img = tf.py_function(
        func=read_tiff_image_with_dynamic_resize,
        inp=[img_path],
        Tout=tf.float32
    )
    img.set_shape([None, None, 3])   # preserve static rank

    # 5) extract patches
    patches = tf.image.extract_patches(
        images=tf.expand_dims(img, 0),
        sizes=[1, patch_size[0], patch_size[1], 1],
        strides=[1, step_size, step_size, 1],
        rates=[1, 1, 1, 1],
        padding='VALID'
    )
    patches = tf.reshape(patches, [-1, patch_size[0], patch_size[1], 3])

    # 6) labels
    labels = tf.fill([tf.shape(patches)[0]], row['Age'])

    # Compute mean intensity per patch, then mask out “empty” ones
    #    (mean over H, W, C → shape [num_patches])
    patch_means = tf.reduce_mean(patches, axis=[1, 2, 3])
    mask = patch_means > THR

    patches = tf.boolean_mask(patches, mask)
    labels  = tf.boolean_mask(labels,  mask)

    return patches, labels

# %%
# Create the RandomRotation layer outside the augmentation function.
rotation_layer = tf.keras.layers.RandomRotation(factor=0.04167)

def advanced_augmentation(image, label):
    # Apply random rotation using the pre-instantiated layer.
    image = rotation_layer(image, training=True)

    # Random Zoom: Scale the image by a factor between 0.9 and 1.1.
    orig_shape = tf.shape(image)[:2]
    zoom_factor = tf.random.uniform([], 0.9, 1.1)
    new_size = tf.cast(tf.cast(orig_shape, tf.float32) * zoom_factor, tf.int32)
    image = tf.image.resize(image, new_size)
    # Crop or pad back to the original dimensions.
    image = tf.image.resize_with_crop_or_pad(image, orig_shape[0], orig_shape[1])

    # Random Contrast (0.75–1.25)
    image = tf.image.random_contrast(image, lower=0.75, upper=1.25)

    # Gaussian Noise: Add noise with a standard deviation of 0.05.
    noise = tf.random.normal(shape=tf.shape(image), mean=0.0, stddev=0.05)
    image = tf.clip_by_value(image + noise, 0., 1.)

    return image, label

# %%
def patch_data_tf_dataset_from_df(
    labels_df_subset,
    data_dir,
    patch_size=(400, 400),
    step_size=200,
    batch_size=BATCH_SIZE,
    augment=False
):
    """
    Like patch_data_tf_dataset, but draws from an arbitrary DataFrame slice
    instead of filtering by 'Set'. Useful for k-fold splits.

    Args:
        labels_df_subset (pd.DataFrame): Subset of labels_data for this fold.
        data_dir (str): Directory containing images (train/val/test all the same).
        patch_size (tuple): Patch height & width.
        step_size (int): Stride for patches.
        batch_size (int): tf.data batch size.
        augment (bool): Whether to apply advanced_augmentation.

    Returns:
        tf.data.Dataset: Batched dataset of (patch, label) pairs.
    """
    ds = tf.data.Dataset.from_tensor_slices(dict(labels_df_subset))
    ds = ds.map(
        lambda row: process_image(row, data_dir, patch_size, step_size),
        num_parallel_calls=tf.data.AUTOTUNE
    ).flat_map(
        lambda patches, labels: tf.data.Dataset.zip((
            tf.data.Dataset.from_tensor_slices(patches),
            tf.data.Dataset.from_tensor_slices(labels)
        ))
    )
    if augment:
        ds = ds.map(
            lambda img, lbl: advanced_augmentation(img, lbl),
            num_parallel_calls=tf.data.AUTOTUNE
        )
    return ds.batch(batch_size).prefetch(tf.data.AUTOTUNE)

# %%
# Define a function to create models using SOTA architectures
def build_sota_model(base_model_fn, input_shape=(400, 400, 3), dropout_rate=0.5):
    base_model = base_model_fn(weights='imagenet', include_top=False, input_shape=input_shape)

    inputs = Input(shape=input_shape)
    x = base_model(inputs, training=False)
    x = GlobalAveragePooling2D()(x)
    x = Dropout(dropout_rate)(x)
    outputs = Dense(1, activation='linear')(x)  # Regression output

    model = Model(inputs, outputs)
    return model

# %%
# if 'mean_patch_intensity' not in CACHE:
#     train_data = labels_data[labels_data['Set'] == 'train']
#     sample_files = train_data.sample(n=200, random_state=42)['File']
#     vals = []
#     for f in sample_files:
#         # Convert the file path string to a TensorFlow constant before passing it
#         # to the tf.py_function wrapped function.
#         arr = read_tiff_image_with_dynamic_resize(tf.constant(os.path.join(train_dir, f)))
#         vals.append(arr.mean())
#     CACHE['mean_patch_intensity'] = np.mean(vals)
THR = 0.0054
print(f"Empty-patch threshold set to {THR:.4f}")
# Out:
# Empty-patch threshold set to 0.0054

# %% [markdown]
# ## Train

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

def compute_evaluation_metrics(true_images, predicted_images):
    """
    Computes evaluation metrics for age prediction models.

    Args:
        true_images (np.ndarray): Array of true ages grouped by image ID.
        predicted_images (np.ndarray): Array of predicted ages grouped by image ID.

    Returns:
        dict: A dictionary containing various evaluation metrics.
    """
    # Compute primary metrics
    mae = mean_absolute_error(true_images, predicted_images)
    rmse = np.sqrt(mean_squared_error(true_images, predicted_images))
    r2 = r2_score(true_images, predicted_images)
    mape = np.mean(np.abs((true_images - predicted_images) / true_images)) * 100

    # Threshold calculations
    def percent_within_threshold(y_true, y_pred, threshold):
        errors = np.abs(y_true - y_pred)
        within = np.sum(errors <= threshold)
        return (within / len(y_true)) * 100

    within_2 = percent_within_threshold(true_images, predicted_images, 2)
    within_5 = percent_within_threshold(true_images, predicted_images, 5)
    within_10 = percent_within_threshold(true_images, predicted_images, 10)

    # Additional statistics
    errors = np.abs(true_images - predicted_images)
    max_error = np.max(errors)
    median_error = np.median(errors)
    cumulative_error_5 = np.mean(errors <= 5) * 100

    # Compile metrics
    metrics = {
        "MAE": mae,
        "RMSE": rmse,
        "R2": r2,
        "MAPE": mape,
        "Within ±2 Years (%)": within_2,
        "Within ±5 Years (%)": within_5,
        "Within ±10 Years (%)": within_10,
        "Max Error": max_error,
        "Median Error": median_error,
        "Cumulative Error ≤ 5 Years (%)": cumulative_error_5,
    }

    for key, value in metrics.items():
        print(f"{key}: {value:.2f}")


    # Create plots
    errors_sorted = np.sort(errors)
    cumulative_percentage = np.arange(1, len(errors_sorted) + 1) / len(errors_sorted) * 100

    fig, axs = plt.subplots(1, 2, figsize=(14, 5))

    # Error Distribution Plot
    axs[0].hist(errors, bins=20, edgecolor='black')
    axs[0].set_title('Error Distribution')
    axs[0].set_xlabel('Prediction Error (Years)')
    axs[0].set_ylabel('Frequency')

    # Cumulative Error Distribution Plot
    axs[1].plot(errors_sorted, cumulative_percentage)
    axs[1].set_title('Cumulative Error Distribution')
    axs[1].set_xlabel('Absolute Error (Years)')
    axs[1].set_ylabel('Cumulative Percentage (%)')
    axs[1].grid(True)

    plt.tight_layout()
    plt.show()

    return metrics

# %%
# Group predictions by 'File' (ImageID)
def group_predictions_by_image_id(predictions_with_ids, labels_df):
    """
    Groups predictions by their `image_id`.
    Args:
        predictions_with_ids (list): List of tuples (prediction, image_id).
        labels_df (pd.DataFrame): DataFrame containing true labels.
    Returns:
        tuple: Grouped predictions and true labels for each image.
    """
    grouped_predictions = defaultdict(list)
    grouped_labels = defaultdict(list)

    # Group predictions by `image_id`
    for pred, image_id in predictions_with_ids:
        # If image_id is bytes, decode; otherwise, use as-is.
        if isinstance(image_id, bytes):
            image_id_str = image_id.decode('utf-8')
        else:
            image_id_str = image_id
        grouped_predictions[image_id_str].append(pred)

    # Match true labels from `labels_df`
    for _, row in labels_df.iterrows():
        file_id = row['File']
        if file_id in grouped_predictions:
            grouped_labels[file_id].append(row['Age'])

    # Filter to only include image IDs present in both predictions and labels
    common_ids = set(grouped_predictions.keys()) & set(grouped_labels.keys())

    predicted_images = [np.mean(grouped_predictions[img_id]) for img_id in common_ids]
    true_images = [np.mean(grouped_labels[img_id]) for img_id in common_ids]

    return np.array(predicted_images), np.array(true_images)

# %%
def process_row_with_id(row):
    """
    Processes a row to generate patches, labels, and use 'File' as the ImageID.
    """
    # Load patches and labels, pointing at the base HHD_AgeSplit folder
    patches, labels = process_image(row, DATA_ROOT, (400,400), 200)

    # Use 'File' as the ImageID
    image_id = tf.fill([tf.shape(patches)[0]], row['File'])
    return patches, labels, image_id

# %%
def patch_data_tf_dataset_with_ids_from_df(
    df_subset,
    data_dir,
    patch_size=(400, 400),
    step_size=200,
    batch_size=128,
    augment=False,
):
    """
    Like patch_data_tf_dataset_with_ids() but takes _any_ DataFrame slice –
    perfect for k-fold splits where val rows are no longer ‘val’ in Set.
    Yields (patch, label, image_id) batched.
    """
    ds = (
        tf.data.Dataset.from_tensor_slices(dict(df_subset))
        .map(process_row_with_id, num_parallel_calls=tf.data.AUTOTUNE)   # ➜ (patches, labels, image_ids)
        .flat_map(
            lambda patches, labels, image_ids: tf.data.Dataset.zip(
                (
                    tf.data.Dataset.from_tensor_slices(patches),
                    tf.data.Dataset.from_tensor_slices(labels),
                    tf.data.Dataset.from_tensor_slices(image_ids),
                )
            )
        )
    )

    if augment:
        ds = ds.map(
            lambda p, l, i: (tf.image.random_flip_left_right(p), l, i),
            num_parallel_calls=tf.data.AUTOTUNE,
        )

    return ds.batch(batch_size).prefetch(tf.data.AUTOTUNE)

# %%
def make_sgkf_splits(df: pd.DataFrame, n_splits=5, random_state=42):
    """
    Returns a list of (train_idx, val_idx) tuples produced by
    StratifiedGroupKFold on writer-level records.

    •  Stratification key  →  AgeGroup
    •  Group key           →  WriterNumber
    """
    sgkf = StratifiedGroupKFold(
        n_splits=n_splits,
        shuffle=True,
        random_state=random_state
    )
    # NOTE: splitter expects X, y, groups
    X      = df.index.values
    y      = df['AgeGroup'].values
    groups = df['WriterNumber'].values

    return list(sgkf.split(X, y, groups))

# %%
def run_cv(
    df_full: pd.DataFrame,
    base_model_fn,
    model_name: str,
    n_splits: int = 5,
    epochs_init: int = 50,
    epochs_ft: int = 10,
    batch_size: int = 64,
    patch_size=(400,400),
    step_size=200,
    dropout=0.5,
):
    # 1) prepare folds
    sgkf = StratifiedGroupKFold(n_splits=n_splits, shuffle=True, random_state=42)
    splits = list(sgkf.split(df_full.index, df_full["AgeGroup"], df_full["WriterNumber"]))
    ckpt_dir = os.path.join(DATA_ROOT, "CV_STRAT_GROUP", model_name)
    os.makedirs(ckpt_dir, exist_ok=True)

    fold_metrics = []

    for fold, (train_idx, val_idx) in enumerate(splits, start=1):
        if model_name in ("ResNet50", "DenseNet121"):
            if fold in (1,5):
                continue

        print(f"\n── {model_name} Fold {fold}/{n_splits} ──")

        # === 2) slice dataframes ===
        train_df = df_full.iloc[train_idx].reset_index(drop=True)
        val_df   = df_full.iloc[val_idx].reset_index(drop=True)

        # === 3) make datasets ===
        train_ds = patch_data_tf_dataset_from_df(
            train_df, DATA_ROOT,
            patch_size=patch_size, step_size=step_size,
            batch_size=batch_size, augment=True
        )
        val_ds   = patch_data_tf_dataset_from_df(
            val_df, DATA_ROOT,
            patch_size=patch_size, step_size=step_size,
            batch_size=batch_size, augment=False
        )

        # === 4) build & warm-up train ===
        model = build_sota_model(base_model_fn,
                                 input_shape=(*patch_size,3),
                                 dropout_rate=dropout)
        backbone = model.layers[1]
        backbone.trainable = False
        model.compile(optimizer="adam", loss="mse", metrics=["mae"])

        ckpt_init = os.path.join(ckpt_dir, f"{model_name}_fold{fold}_init.keras")
        callbacks = [
            ModelCheckpoint(ckpt_init, monitor="val_mae", save_best_only=True, verbose=1),
            ReduceLROnPlateau(monitor="val_mae", factor=0.2, patience=4, verbose=1),
            EarlyStopping(    monitor="val_mae", patience=8, restore_best_weights=True, verbose=1),
        ]
        history = model.fit(train_ds,
                            validation_data=val_ds,
                            epochs=epochs_init,
                            callbacks=callbacks,
                            verbose=2)

        # === 5) CLEANUP before fine-tune ===
        print("🧹 Clearing memory before fine-tune…")
        # delete large objects no longer needed
        del train_ds, val_ds, history, callbacks
        gc.collect()
        tf.keras.backend.clear_session()
        gc.collect()

        # === 6) rebuild model & load warm-up weights ===
        model = build_sota_model(base_model_fn,
                                 input_shape=(*patch_size,3),
                                 dropout_rate=dropout)
        model.load_weights(ckpt_init)
        backbone = model.layers[1]
        backbone.trainable = True
        model.compile(optimizer=tf.keras.optimizers.Adam(1e-4),
                      loss="mse", metrics=["mae"])

        # === 7) re-create datasets for fine-tune ===
        train_ds = patch_data_tf_dataset_from_df(
            train_df, DATA_ROOT,
            patch_size=patch_size, step_size=step_size,
            batch_size=batch_size, augment=True
        )
        val_ds   = patch_data_tf_dataset_from_df(
            val_df, DATA_ROOT,
            patch_size=patch_size, step_size=step_size,
            batch_size=batch_size, augment=False
        )

        ckpt_ft = os.path.join(ckpt_dir, f"{model_name}_fold{fold}_ft.keras")
        callbacks = [
            ModelCheckpoint(ckpt_ft, monitor="val_mae", save_best_only=True, verbose=1),
            ReduceLROnPlateau(monitor="val_mae", factor=0.2, patience=4, verbose=1),
            EarlyStopping(    monitor="val_mae", patience=8, restore_best_weights=True, verbose=1),
        ]
        history_ft = model.fit(train_ds,
                               validation_data=val_ds,
                               epochs=epochs_ft,
                               callbacks=callbacks,
                               verbose=2)

        # === 8) EVALUATE (image-level) ===
        del train_ds, history_ft, callbacks    # free again before eval
        gc.collect()

        val_ids_ds = patch_data_tf_dataset_with_ids_from_df(
            val_df, DATA_ROOT,
            patch_size=patch_size, step_size=step_size,
            batch_size=batch_size, augment=False
        )
        preds = []
        for patches, _, img_ids in val_ids_ds:
            p = model.predict(patches, verbose=0).ravel()
            preds.extend(zip(p, img_ids.numpy()))

        y_pred_img, y_true_img = group_predictions_by_image_id(preds, val_df)
        metrics = compute_evaluation_metrics(y_true_img, y_pred_img)
        fold_metrics.append(metrics)

        # pretty-print
        keys = ["MAE","RMSE","R2","MAPE"]
        summary = " │ ".join(f"{k} {metrics[k]:.2f}" for k in keys if k in metrics)
        print(f"Fold {fold}: {summary}")

        # === 9) FINAL CLEANUP of this fold ===
        del val_ids_ds, preds, y_pred_img, y_true_img
        del train_df, val_df, model
        gc.collect()
        tf.keras.backend.clear_session()
        gc.collect()

    # === 10) AGGREGATE all folds ===
    print("\n══════ CV SUMMARY ══════")
    for k in fold_metrics[0].keys():
        arr = np.array([fm[k] for fm in fold_metrics], dtype=float)
        print(f"{k:<25}: {arr.mean():.2f} ± {arr.std():.2f}")

    return fold_metrics

# %%
# Define SOTA models
models = {
    # 'ResNet50': ResNet50,
    'DenseNet121': DenseNet121,
    'InceptionV3': InceptionV3,
    'InceptionResNetV2': InceptionResNetV2,
    'EfficientNetV2M': EfficientNetV2M
}

df_full = pd.read_csv(csv_dir)

cv_stats = {}
for name, fn in models.items():
    cv_stats[name] = run_cv(
        df_full = df_full,
        base_model_fn = fn,
        model_name    = name,
        n_splits      = 5,
        batch_size    = 64,
    )

print(cv_stats)
# Out:
# ── DenseNet121 Fold 2/5 ──
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/epoch_iterator.py:151: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# Epoch 1: val_mae improved from inf to 9.16425, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold2_init.keras
# 311/311 - 214s - 689ms/step - loss: 171.8519 - mae: 8.1055 - val_loss: 133.7115 - val_mae: 9.1643 - learning_rate: 1.0000e-03
# Epoch 2/50
#
# Epoch 2: val_mae improved from 9.16425 to 8.88648, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold2_init.keras
# 311/311 - 110s - 354ms/step - loss: 142.7874 - mae: 7.9397 - val_loss: 129.3735 - val_mae: 8.8865 - learning_rate: 1.0000e-03
# Epoch 3/50
#
# Epoch 3: val_mae improved from 8.88648 to 8.77337, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold2_init.keras
# 311/311 - 110s - 354ms/step - loss: 138.7825 - mae: 7.8041 - val_loss: 127.2872 - val_mae: 8.7734 - learning_rate: 1.0000e-03
# Epoch 4/50
#
# Epoch 4: val_mae did not improve from 8.77337
# 311/311 - 109s - 349ms/step - loss: 136.4113 - mae: 7.7791 - val_loss: 126.6115 - val_mae: 8.7771 - learning_rate: 1.0000e-03
# Epoch 5/50
#
# Epoch 5: val_mae did not improve from 8.77337
# 311/311 - 108s - 349ms/step - loss: 134.2194 - mae: 7.7439 - val_loss: 126.6329 - val_mae: 8.8341 - learning_rate: 1.0000e-03
# Epoch 6/50
#
# Epoch 6: val_mae did not improve from 8.77337
# 311/311 - 108s - 349ms/step - loss: 132.8779 - mae: 7.7070 - val_loss: 126.6246 - val_mae: 8.8750 - learning_rate: 1.0000e-03
# Epoch 7/50
#
# Epoch 7: val_mae did not improve from 8.77337
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 311/311 - 109s - 350ms/step - loss: 131.6884 - mae: 7.7104 - val_loss: 127.4816 - val_mae: 8.9829 - learning_rate: 1.0000e-03
# Epoch 8/50
#
# Epoch 8: val_mae improved from 8.77337 to 7.30805, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold2_init.keras
# 311/311 - 110s - 353ms/step - loss: 167.8033 - mae: 10.1874 - val_loss: 120.1970 - val_mae: 7.3080 - learning_rate: 2.0000e-04
# Epoch 9/50
#
# Epoch 9: val_mae improved from 7.30805 to 7.24272, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold2_init.keras
# 311/311 - 111s - 356ms/step - loss: 137.2278 - mae: 8.3763 - val_loss: 124.5436 - val_mae: 7.2427 - learning_rate: 2.0000e-04
# Epoch 10/50
#
# Epoch 10: val_mae improved from 7.24272 to 7.22770, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold2_init.keras
# 311/311 - 110s - 355ms/step - loss: 134.6747 - mae: 8.1181 - val_loss: 125.0743 - val_mae: 7.2277 - learning_rate: 2.0000e-04
# Epoch 11/50
#
# Epoch 11: val_mae improved from 7.22770 to 7.21474, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold2_init.keras
# 311/311 - 110s - 354ms/step - loss: 134.7013 - mae: 8.0717 - val_loss: 124.8168 - val_mae: 7.2147 - learning_rate: 2.0000e-04
# Epoch 12/50
#
# Epoch 12: val_mae improved from 7.21474 to 7.20408, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold2_init.keras
# 311/311 - 110s - 353ms/step - loss: 133.8869 - mae: 8.0290 - val_loss: 124.3183 - val_mae: 7.2041 - learning_rate: 2.0000e-04
# Epoch 13/50
#
# Epoch 13: val_mae improved from 7.20408 to 7.19487, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold2_init.keras
# 311/311 - 110s - 354ms/step - loss: 133.3852 - mae: 8.0069 - val_loss: 123.6612 - val_mae: 7.1949 - learning_rate: 2.0000e-04
# Epoch 14/50
#
# Epoch 14: val_mae improved from 7.19487 to 7.18540, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold2_init.keras
# 311/311 - 110s - 354ms/step - loss: 133.2158 - mae: 8.0035 - val_loss: 123.2429 - val_mae: 7.1854 - learning_rate: 2.0000e-04
# Epoch 15/50
#
# Epoch 15: val_mae improved from 7.18540 to 7.17543, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold2_init.keras
# 311/311 - 110s - 355ms/step - loss: 132.7691 - mae: 7.9994 - val_loss: 123.0885 - val_mae: 7.1754 - learning_rate: 2.0000e-04
# Epoch 16/50
#
# Epoch 16: val_mae improved from 7.17543 to 7.16607, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold2_init.keras
# 311/311 - 110s - 353ms/step - loss: 132.8049 - mae: 7.9873 - val_loss: 122.6406 - val_mae: 7.1661 - learning_rate: 2.0000e-04
# Epoch 17/50
#
# Epoch 17: val_mae improved from 7.16607 to 7.15748, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold2_init.keras
# 311/311 - 110s - 355ms/step - loss: 132.5355 - mae: 7.9762 - val_loss: 122.2851 - val_mae: 7.1575 - learning_rate: 2.0000e-04
# Epoch 18/50
#
# Epoch 18: val_mae improved from 7.15748 to 7.14908, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold2_init.keras
# 311/311 - 111s - 356ms/step - loss: 132.2573 - mae: 7.9520 - val_loss: 122.0088 - val_mae: 7.1491 - learning_rate: 2.0000e-04
# Epoch 19/50
#
# Epoch 19: val_mae improved from 7.14908 to 7.14087, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold2_init.keras
# 311/311 - 110s - 354ms/step - loss: 132.0730 - mae: 7.9667 - val_loss: 121.7184 - val_mae: 7.1409 - learning_rate: 2.0000e-04
# Epoch 20/50
#
# Epoch 20: val_mae improved from 7.14087 to 7.13180, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold2_init.keras
# 311/311 - 110s - 354ms/step - loss: 131.6213 - mae: 7.9513 - val_loss: 121.4405 - val_mae: 7.1318 - learning_rate: 2.0000e-04
# Epoch 21/50
#
# Epoch 21: val_mae improved from 7.13180 to 7.12466, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold2_init.keras
# 311/311 - 110s - 353ms/step - loss: 131.9253 - mae: 7.9401 - val_loss: 121.1536 - val_mae: 7.1247 - learning_rate: 2.0000e-04
# Epoch 22/50
#
# Epoch 22: val_mae improved from 7.12466 to 7.11736, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold2_init.keras
# 311/311 - 110s - 353ms/step - loss: 131.5766 - mae: 7.9255 - val_loss: 120.7084 - val_mae: 7.1174 - learning_rate: 2.0000e-04
# Epoch 23/50
#
# Epoch 23: val_mae improved from 7.11736 to 7.10924, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold2_init.keras
# 311/311 - 110s - 353ms/step - loss: 132.0947 - mae: 7.9467 - val_loss: 120.5267 - val_mae: 7.1092 - learning_rate: 2.0000e-04
# Epoch 24/50
#
# Epoch 24: val_mae improved from 7.10924 to 7.10115, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold2_init.keras
# 311/311 - 110s - 353ms/step - loss: 131.0236 - mae: 7.9054 - val_loss: 120.1309 - val_mae: 7.1011 - learning_rate: 2.0000e-04
# Epoch 25/50
#
# Epoch 25: val_mae improved from 7.10115 to 7.09416, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold2_init.keras
# 311/311 - 110s - 355ms/step - loss: 130.9579 - mae: 7.9083 - val_loss: 119.9015 - val_mae: 7.0942 - learning_rate: 2.0000e-04
# Epoch 26/50
#
# Epoch 26: val_mae improved from 7.09416 to 7.08812, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold2_init.keras
# 311/311 - 110s - 353ms/step - loss: 131.2899 - mae: 7.9049 - val_loss: 119.6129 - val_mae: 7.0881 - learning_rate: 2.0000e-04
# Epoch 27/50
#
# Epoch 27: val_mae improved from 7.08812 to 7.08202, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold2_init.keras
# 311/311 - 110s - 354ms/step - loss: 131.1133 - mae: 7.9156 - val_loss: 119.4160 - val_mae: 7.0820 - learning_rate: 2.0000e-04
# Epoch 28/50
#
# Epoch 28: val_mae improved from 7.08202 to 7.07490, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold2_init.keras
# 311/311 - 110s - 353ms/step - loss: 130.4036 - mae: 7.8781 - val_loss: 119.2579 - val_mae: 7.0749 - learning_rate: 2.0000e-04
# Epoch 29/50
#
# Epoch 29: val_mae improved from 7.07490 to 7.06825, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold2_init.keras
# 311/311 - 111s - 356ms/step - loss: 130.6850 - mae: 7.8821 - val_loss: 119.1264 - val_mae: 7.0682 - learning_rate: 2.0000e-04
# Epoch 30/50
#
# Epoch 30: val_mae improved from 7.06825 to 7.06107, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold2_init.keras
# 311/311 - 110s - 354ms/step - loss: 130.4507 - mae: 7.8872 - val_loss: 118.9225 - val_mae: 7.0611 - learning_rate: 2.0000e-04
# Epoch 31/50
#
# Epoch 31: val_mae improved from 7.06107 to 7.05428, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold2_init.keras
# 311/311 - 110s - 354ms/step - loss: 129.7953 - mae: 7.8753 - val_loss: 118.7553 - val_mae: 7.0543 - learning_rate: 2.0000e-04
# Epoch 32/50
#
# Epoch 32: val_mae improved from 7.05428 to 7.04828, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold2_init.keras
# 311/311 - 110s - 355ms/step - loss: 129.8854 - mae: 7.8484 - val_loss: 118.5736 - val_mae: 7.0483 - learning_rate: 2.0000e-04
# Epoch 33/50
#
# Epoch 33: val_mae improved from 7.04828 to 7.04098, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold2_init.keras
# 311/311 - 110s - 354ms/step - loss: 130.1227 - mae: 7.8771 - val_loss: 118.5754 - val_mae: 7.0410 - learning_rate: 2.0000e-04
# Epoch 34/50
#
# Epoch 34: val_mae improved from 7.04098 to 7.03578, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold2_init.keras
# 311/311 - 109s - 351ms/step - loss: 129.9800 - mae: 7.8594 - val_loss: 118.3012 - val_mae: 7.0358 - learning_rate: 2.0000e-04
# Epoch 35/50
#
# Epoch 35: val_mae improved from 7.03578 to 7.03208, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold2_init.keras
# 311/311 - 110s - 353ms/step - loss: 129.9280 - mae: 7.8437 - val_loss: 117.8801 - val_mae: 7.0321 - learning_rate: 2.0000e-04
# Epoch 36/50
#
# Epoch 36: val_mae improved from 7.03208 to 7.02491, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold2_init.keras
# 311/311 - 110s - 354ms/step - loss: 129.7668 - mae: 7.8570 - val_loss: 117.8528 - val_mae: 7.0249 - learning_rate: 2.0000e-04
# Epoch 37/50
#
# Epoch 37: val_mae improved from 7.02491 to 7.01873, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold2_init.keras
# 311/311 - 110s - 354ms/step - loss: 130.1941 - mae: 7.8676 - val_loss: 117.7288 - val_mae: 7.0187 - learning_rate: 2.0000e-04
# Epoch 38/50
#
# Epoch 38: val_mae improved from 7.01873 to 7.01395, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold2_init.keras
# 311/311 - 110s - 354ms/step - loss: 130.3855 - mae: 7.8430 - val_loss: 117.5148 - val_mae: 7.0139 - learning_rate: 2.0000e-04
# Epoch 39/50
#
# Epoch 39: val_mae improved from 7.01395 to 7.00967, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold2_init.keras
# 311/311 - 110s - 353ms/step - loss: 129.5646 - mae: 7.8354 - val_loss: 117.3125 - val_mae: 7.0097 - learning_rate: 2.0000e-04
# Epoch 40/50
#
# Epoch 40: val_mae improved from 7.00967 to 7.00442, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold2_init.keras
# 311/311 - 110s - 355ms/step - loss: 130.0863 - mae: 7.8529 - val_loss: 117.3237 - val_mae: 7.0044 - learning_rate: 2.0000e-04
# Epoch 41/50
#
# Epoch 41: val_mae improved from 7.00442 to 7.00001, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold2_init.keras
# 311/311 - 110s - 352ms/step - loss: 129.8819 - mae: 7.8398 - val_loss: 117.0756 - val_mae: 7.0000 - learning_rate: 2.0000e-04
# Epoch 42/50
#
# Epoch 42: val_mae improved from 7.00001 to 6.99506, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold2_init.keras
# 311/311 - 110s - 354ms/step - loss: 128.4333 - mae: 7.8166 - val_loss: 116.9401 - val_mae: 6.9951 - learning_rate: 2.0000e-04
# Epoch 43/50
#
# Epoch 43: val_mae improved from 6.99506 to 6.99018, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold2_init.keras
# 311/311 - 110s - 352ms/step - loss: 129.1637 - mae: 7.8076 - val_loss: 116.7772 - val_mae: 6.9902 - learning_rate: 2.0000e-04
# Epoch 44/50
#
# Epoch 44: val_mae improved from 6.99018 to 6.98558, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold2_init.keras
# 311/311 - 109s - 351ms/step - loss: 129.0632 - mae: 7.8279 - val_loss: 116.7649 - val_mae: 6.9856 - learning_rate: 2.0000e-04
# Epoch 45/50
#
# Epoch 45: val_mae improved from 6.98558 to 6.98002, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold2_init.keras
# 311/311 - 110s - 353ms/step - loss: 129.0486 - mae: 7.8354 - val_loss: 116.6270 - val_mae: 6.9800 - learning_rate: 2.0000e-04
# Epoch 46/50
#
# Epoch 46: val_mae improved from 6.98002 to 6.97453, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold2_init.keras
# 311/311 - 110s - 353ms/step - loss: 128.4423 - mae: 7.8073 - val_loss: 116.5466 - val_mae: 6.9745 - learning_rate: 2.0000e-04
# Epoch 47/50
#
# Epoch 47: val_mae improved from 6.97453 to 6.97033, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold2_init.keras
# 311/311 - 111s - 358ms/step - loss: 129.0858 - mae: 7.8130 - val_loss: 116.3674 - val_mae: 6.9703 - learning_rate: 2.0000e-04
# Epoch 48/50
#
# Epoch 48: val_mae improved from 6.97033 to 6.96544, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold2_init.keras
# 311/311 - 110s - 354ms/step - loss: 127.9279 - mae: 7.7763 - val_loss: 116.2329 - val_mae: 6.9654 - learning_rate: 2.0000e-04
# Epoch 49/50
#
# Epoch 49: val_mae improved from 6.96544 to 6.96045, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold2_init.keras
# 311/311 - 110s - 354ms/step - loss: 128.8404 - mae: 7.8360 - val_loss: 116.2316 - val_mae: 6.9604 - learning_rate: 2.0000e-04
# Epoch 50/50
#
# Epoch 50: val_mae improved from 6.96045 to 6.95598, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold2_init.keras
# 311/311 - 110s - 354ms/step - loss: 127.9968 - mae: 7.7843 - val_loss: 116.0528 - val_mae: 6.9560 - learning_rate: 2.0000e-04
# Restoring model weights from the end of the best epoch: 50.
# 🧹 Clearing memory before fine-tune…
# Epoch 1/10
#
# Epoch 1: val_mae improved from inf to 16.56125, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold2_ft.keras
# 311/311 - 449s - 1s/step - loss: 125.3880 - mae: 7.2122 - val_loss: 395.4742 - val_mae: 16.5612 - learning_rate: 1.0000e-04
# Epoch 2/10
#
# Epoch 2: val_mae improved from 16.56125 to 8.98536, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold2_ft.keras
# 311/311 - 135s - 436ms/step - loss: 96.6082 - mae: 6.4937 - val_loss: 129.1406 - val_mae: 8.9854 - learning_rate: 1.0000e-04
# Epoch 3/10
#
# Epoch 3: val_mae improved from 8.98536 to 7.57185, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold2_ft.keras
# 311/311 - 136s - 437ms/step - loss: 126.2435 - mae: 7.3338 - val_loss: 120.4499 - val_mae: 7.5719 - learning_rate: 1.0000e-04
# Epoch 4/10
#
# Epoch 4: val_mae improved from 7.57185 to 7.22300, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold2_ft.keras
# 311/311 - 136s - 439ms/step - loss: 121.6484 - mae: 7.0555 - val_loss: 131.9466 - val_mae: 7.2230 - learning_rate: 1.0000e-04
# Epoch 5/10
#
# Epoch 5: val_mae did not improve from 7.22300
# 311/311 - 134s - 430ms/step - loss: 116.4268 - mae: 6.9348 - val_loss: 192.2866 - val_mae: 8.6549 - learning_rate: 1.0000e-04
# Epoch 6/10
#
# Epoch 6: val_mae did not improve from 7.22300
# 311/311 - 134s - 430ms/step - loss: 125.3100 - mae: 7.3549 - val_loss: 125.8714 - val_mae: 7.2873 - learning_rate: 1.0000e-04
# Epoch 7/10
#
# Epoch 7: val_mae did not improve from 7.22300
# 311/311 - 133s - 428ms/step - loss: 119.6299 - mae: 7.1414 - val_loss: 149.5236 - val_mae: 7.3551 - learning_rate: 1.0000e-04
# Epoch 8/10
#
# Epoch 8: val_mae did not improve from 7.22300
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 311/311 - 133s - 427ms/step - loss: 124.4682 - mae: 7.4820 - val_loss: 119.5837 - val_mae: 7.5180 - learning_rate: 1.0000e-04
# Epoch 9/10
#
# Epoch 9: val_mae did not improve from 7.22300
# 311/311 - 133s - 426ms/step - loss: 164.3446 - mae: 9.6750 - val_loss: 118.6469 - val_mae: 7.7209 - learning_rate: 2.0000e-05
# Epoch 10/10
#
# Epoch 10: val_mae did not improve from 7.22300
# 311/311 - 133s - 428ms/step - loss: 127.0575 - mae: 7.7158 - val_loss: 118.8303 - val_mae: 7.9097 - learning_rate: 2.0000e-05
# Restoring model weights from the end of the best epoch: 4.
# MAE: 7.64
# RMSE: 11.98
# R2: -0.11
# MAPE: 28.68
# Within ±2 Years (%): 16.06
# Within ±5 Years (%): 62.39
# Within ±10 Years (%): 80.73
# Max Error: 59.10
# Median Error: 4.63
# Cumulative Error ≤ 5 Years (%): 62.39
# Fold 2: MAE 7.64 │ RMSE 11.98 │ R2 -0.11 │ MAPE 28.68
#
# ── DenseNet121 Fold 3/5 ──
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/epoch_iterator.py:151: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# Epoch 1: val_mae improved from inf to 10.23574, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold3_init.keras
# 292/292 - 172s - 588ms/step - loss: 164.8084 - mae: 7.8791 - val_loss: 174.7010 - val_mae: 10.2357 - learning_rate: 1.0000e-03
# Epoch 2/50
#
# Epoch 2: val_mae did not improve from 10.23574
# 292/292 - 106s - 362ms/step - loss: 119.3993 - mae: 7.4374 - val_loss: 173.5222 - val_mae: 10.2423 - learning_rate: 1.0000e-03
# Epoch 3/50
#
# Epoch 3: val_mae did not improve from 10.23574
# 292/292 - 106s - 362ms/step - loss: 116.4526 - mae: 7.3094 - val_loss: 173.0188 - val_mae: 10.2796 - learning_rate: 1.0000e-03
# Epoch 4/50
#
# Epoch 4: val_mae did not improve from 10.23574
# 292/292 - 105s - 360ms/step - loss: 114.5631 - mae: 7.2562 - val_loss: 173.3737 - val_mae: 10.3578 - learning_rate: 1.0000e-03
# Epoch 5/50
#
# Epoch 5: val_mae did not improve from 10.23574
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 292/292 - 105s - 361ms/step - loss: 113.3056 - mae: 7.2138 - val_loss: 172.7033 - val_mae: 10.3604 - learning_rate: 1.0000e-03
# Epoch 6/50
#
# Epoch 6: val_mae improved from 10.23574 to 8.34433, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold3_init.keras
# 292/292 - 107s - 365ms/step - loss: 156.2236 - mae: 9.8253 - val_loss: 152.8909 - val_mae: 8.3443 - learning_rate: 2.0000e-04
# Epoch 7/50
#
# Epoch 7: val_mae improved from 8.34433 to 8.18753, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold3_init.keras
# 292/292 - 107s - 365ms/step - loss: 128.8815 - mae: 8.1806 - val_loss: 154.8984 - val_mae: 8.1875 - learning_rate: 2.0000e-04
# Epoch 8/50
#
# Epoch 8: val_mae improved from 8.18753 to 8.17009, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold3_init.keras
# 292/292 - 106s - 364ms/step - loss: 126.6966 - mae: 7.9132 - val_loss: 155.0839 - val_mae: 8.1701 - learning_rate: 2.0000e-04
# Epoch 9/50
#
# Epoch 9: val_mae improved from 8.17009 to 8.16940, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold3_init.keras
# 292/292 - 108s - 370ms/step - loss: 125.6373 - mae: 7.8589 - val_loss: 154.8285 - val_mae: 8.1694 - learning_rate: 2.0000e-04
# Epoch 10/50
#
# Epoch 10: val_mae did not improve from 8.16940
# 292/292 - 106s - 362ms/step - loss: 125.2130 - mae: 7.8225 - val_loss: 154.5067 - val_mae: 8.1716 - learning_rate: 2.0000e-04
# Epoch 11/50
#
# Epoch 11: val_mae did not improve from 8.16940
# 292/292 - 105s - 360ms/step - loss: 124.7202 - mae: 7.7984 - val_loss: 154.1162 - val_mae: 8.1801 - learning_rate: 2.0000e-04
# Epoch 12/50
#
# Epoch 12: val_mae did not improve from 8.16940
# 292/292 - 105s - 360ms/step - loss: 124.6717 - mae: 7.7883 - val_loss: 153.8440 - val_mae: 8.1829 - learning_rate: 2.0000e-04
# Epoch 13/50
#
# Epoch 13: val_mae did not improve from 8.16940
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 292/292 - 106s - 362ms/step - loss: 124.4557 - mae: 7.7918 - val_loss: 153.6320 - val_mae: 8.1837 - learning_rate: 2.0000e-04
# Epoch 14/50
#
# Epoch 14: val_mae improved from 8.16940 to 8.16706, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold3_init.keras
# 292/292 - 106s - 364ms/step - loss: 121.8144 - mae: 7.6778 - val_loss: 153.8913 - val_mae: 8.1671 - learning_rate: 4.0000e-05
# Epoch 15/50
#
# Epoch 15: val_mae improved from 8.16706 to 8.15547, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold3_init.keras
# 292/292 - 106s - 365ms/step - loss: 121.5251 - mae: 7.6305 - val_loss: 154.0706 - val_mae: 8.1555 - learning_rate: 4.0000e-05
# Epoch 16/50
#
# Epoch 16: val_mae improved from 8.15547 to 8.14785, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold3_init.keras
# 292/292 - 107s - 366ms/step - loss: 120.8116 - mae: 7.5786 - val_loss: 154.1852 - val_mae: 8.1479 - learning_rate: 4.0000e-05
# Epoch 17/50
#
# Epoch 17: val_mae improved from 8.14785 to 8.14276, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold3_init.keras
# 292/292 - 107s - 366ms/step - loss: 121.3052 - mae: 7.5865 - val_loss: 154.2557 - val_mae: 8.1428 - learning_rate: 4.0000e-05
# Epoch 18/50
#
# Epoch 18: val_mae improved from 8.14276 to 8.13903, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold3_init.keras
# 292/292 - 107s - 365ms/step - loss: 121.1799 - mae: 7.5830 - val_loss: 154.3001 - val_mae: 8.1390 - learning_rate: 4.0000e-05
# Epoch 19/50
#
# Epoch 19: val_mae improved from 8.13903 to 8.13685, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold3_init.keras
# 292/292 - 107s - 366ms/step - loss: 120.7775 - mae: 7.5490 - val_loss: 154.3059 - val_mae: 8.1368 - learning_rate: 4.0000e-05
# Epoch 20/50
#
# Epoch 20: val_mae improved from 8.13685 to 8.13378, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold3_init.keras
# 292/292 - 107s - 365ms/step - loss: 121.1656 - mae: 7.5521 - val_loss: 154.3324 - val_mae: 8.1338 - learning_rate: 4.0000e-05
# Epoch 21/50
#
# Epoch 21: val_mae improved from 8.13378 to 8.13288, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold3_init.keras
# 292/292 - 107s - 366ms/step - loss: 120.7954 - mae: 7.5277 - val_loss: 154.3051 - val_mae: 8.1329 - learning_rate: 4.0000e-05
# Epoch 22/50
#
# Epoch 22: val_mae did not improve from 8.13288
# 292/292 - 106s - 362ms/step - loss: 120.8098 - mae: 7.5201 - val_loss: 154.2306 - val_mae: 8.1344 - learning_rate: 4.0000e-05
# Epoch 23/50
#
# Epoch 23: val_mae did not improve from 8.13288
# 292/292 - 106s - 362ms/step - loss: 120.9629 - mae: 7.5400 - val_loss: 154.1913 - val_mae: 8.1345 - learning_rate: 4.0000e-05
# Epoch 24/50
#
# Epoch 24: val_mae did not improve from 8.13288
# 292/292 - 105s - 360ms/step - loss: 120.1327 - mae: 7.5057 - val_loss: 154.1408 - val_mae: 8.1351 - learning_rate: 4.0000e-05
# Epoch 25/50
#
# Epoch 25: val_mae did not improve from 8.13288
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 292/292 - 105s - 360ms/step - loss: 120.4544 - mae: 7.5128 - val_loss: 154.1008 - val_mae: 8.1351 - learning_rate: 4.0000e-05
# Epoch 26/50
#
# Epoch 26: val_mae did not improve from 8.13288
# 292/292 - 105s - 360ms/step - loss: 119.3243 - mae: 7.4320 - val_loss: 154.0903 - val_mae: 8.1352 - learning_rate: 8.0000e-06
# Epoch 27/50
#
# Epoch 27: val_mae did not improve from 8.13288
# 292/292 - 106s - 361ms/step - loss: 119.2611 - mae: 7.4291 - val_loss: 154.0825 - val_mae: 8.1351 - learning_rate: 8.0000e-06
# Epoch 28/50
#
# Epoch 28: val_mae did not improve from 8.13288
# 292/292 - 105s - 360ms/step - loss: 119.4392 - mae: 7.4483 - val_loss: 154.0732 - val_mae: 8.1352 - learning_rate: 8.0000e-06
# Epoch 29/50
#
# Epoch 29: val_mae did not improve from 8.13288
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 292/292 - 105s - 361ms/step - loss: 119.7028 - mae: 7.4743 - val_loss: 154.0641 - val_mae: 8.1353 - learning_rate: 8.0000e-06
# Epoch 29: early stopping
# Restoring model weights from the end of the best epoch: 21.
# 🧹 Clearing memory before fine-tune…
# Epoch 1/10
#
# Epoch 1: val_mae improved from inf to 10.28015, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold3_ft.keras
# 292/292 - 423s - 1s/step - loss: 97.6856 - mae: 6.5236 - val_loss: 169.2293 - val_mae: 10.2801 - learning_rate: 1.0000e-04
# Epoch 2/10
#
# Epoch 2: val_mae did not improve from 10.28015
# 292/292 - 129s - 440ms/step - loss: 100.8115 - mae: 6.6581 - val_loss: 357.1842 - val_mae: 17.6262 - learning_rate: 1.0000e-04
# Epoch 3/10
#
# Epoch 3: val_mae did not improve from 10.28015
# 292/292 - 128s - 440ms/step - loss: 97.9854 - mae: 6.5679 - val_loss: 240.5255 - val_mae: 13.9287 - learning_rate: 1.0000e-04
# Epoch 4/10
#
# Epoch 4: val_mae improved from 10.28015 to 8.07299, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold3_ft.keras
# 292/292 - 130s - 447ms/step - loss: 100.2707 - mae: 6.7563 - val_loss: 154.8540 - val_mae: 8.0730 - learning_rate: 1.0000e-04
# Epoch 5/10
#
# Epoch 5: val_mae did not improve from 8.07299
# 292/292 - 128s - 440ms/step - loss: 98.4120 - mae: 6.4844 - val_loss: 244.1973 - val_mae: 9.9522 - learning_rate: 1.0000e-04
# Epoch 6/10
#
# Epoch 6: val_mae did not improve from 8.07299
# 292/292 - 128s - 440ms/step - loss: 88.4018 - mae: 6.2145 - val_loss: 198.2911 - val_mae: 8.5578 - learning_rate: 1.0000e-04
# Epoch 7/10
#
# Epoch 7: val_mae did not improve from 8.07299
# 292/292 - 129s - 440ms/step - loss: 81.8096 - mae: 6.0079 - val_loss: 148.7590 - val_mae: 8.4244 - learning_rate: 1.0000e-04
# Epoch 8/10
#
# Epoch 8: val_mae did not improve from 8.07299
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 292/292 - 128s - 440ms/step - loss: 80.2299 - mae: 6.0240 - val_loss: 150.7472 - val_mae: 8.8486 - learning_rate: 1.0000e-04
# Epoch 9/10
#
# Epoch 9: val_mae did not improve from 8.07299
# 292/292 - 128s - 439ms/step - loss: 115.6336 - mae: 7.5435 - val_loss: 151.6962 - val_mae: 8.9436 - learning_rate: 2.0000e-05
# Epoch 10/10
#
# Epoch 10: val_mae did not improve from 8.07299
# 292/292 - 129s - 440ms/step - loss: 110.4444 - mae: 7.6319 - val_loss: 149.4488 - val_mae: 8.6881 - learning_rate: 2.0000e-05
# Restoring model weights from the end of the best epoch: 4.
# MAE: 8.49
# RMSE: 13.15
# R2: -0.06
# MAPE: 35.92
# Within ±2 Years (%): 8.40
# Within ±5 Years (%): 46.18
# Within ±10 Years (%): 85.11
# Max Error: 72.16
# Median Error: 5.47
# Cumulative Error ≤ 5 Years (%): 46.18
# Fold 3: MAE 8.49 │ RMSE 13.15 │ R2 -0.06 │ MAPE 35.92
#
# ── DenseNet121 Fold 4/5 ──
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/epoch_iterator.py:151: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# Epoch 1: val_mae improved from inf to 9.46347, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold4_init.keras
# 318/318 - 178s - 560ms/step - loss: 188.9900 - mae: 8.5339 - val_loss: 134.9137 - val_mae: 9.4635 - learning_rate: 1.0000e-03
# Epoch 2/50
#
# Epoch 2: val_mae improved from 9.46347 to 9.34531, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold4_init.keras
# 318/318 - 111s - 349ms/step - loss: 145.3726 - mae: 8.1275 - val_loss: 131.7716 - val_mae: 9.3453 - learning_rate: 1.0000e-03
# Epoch 3/50
#
# Epoch 3: val_mae improved from 9.34531 to 9.27565, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold4_init.keras
# 318/318 - 110s - 347ms/step - loss: 142.0248 - mae: 8.0088 - val_loss: 129.7365 - val_mae: 9.2757 - learning_rate: 1.0000e-03
# Epoch 4/50
#
# Epoch 4: val_mae improved from 9.27565 to 9.26820, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold4_init.keras
# 318/318 - 111s - 350ms/step - loss: 140.2945 - mae: 7.9582 - val_loss: 128.9057 - val_mae: 9.2682 - learning_rate: 1.0000e-03
# Epoch 5/50
#
# Epoch 5: val_mae did not improve from 9.26820
# 318/318 - 110s - 346ms/step - loss: 137.4984 - mae: 7.8793 - val_loss: 130.9136 - val_mae: 9.4248 - learning_rate: 1.0000e-03
# Epoch 6/50
#
# Epoch 6: val_mae did not improve from 9.26820
# 318/318 - 110s - 347ms/step - loss: 136.2881 - mae: 7.8833 - val_loss: 131.6401 - val_mae: 9.4937 - learning_rate: 1.0000e-03
# Epoch 7/50
#
# Epoch 7: val_mae did not improve from 9.26820
# 318/318 - 110s - 347ms/step - loss: 134.5536 - mae: 7.8390 - val_loss: 132.0293 - val_mae: 9.5385 - learning_rate: 1.0000e-03
# Epoch 8/50
#
# Epoch 8: val_mae did not improve from 9.26820
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 318/318 - 110s - 346ms/step - loss: 134.4424 - mae: 7.8290 - val_loss: 132.1345 - val_mae: 9.5612 - learning_rate: 1.0000e-03
# Epoch 9/50
#
# Epoch 9: val_mae improved from 9.26820 to 6.81001, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold4_init.keras
# 318/318 - 111s - 349ms/step - loss: 167.1837 - mae: 10.0984 - val_loss: 96.1448 - val_mae: 6.8100 - learning_rate: 2.0000e-04
# Epoch 10/50
#
# Epoch 10: val_mae improved from 6.81001 to 6.52340, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold4_init.keras
# 318/318 - 111s - 349ms/step - loss: 140.9785 - mae: 8.5598 - val_loss: 95.1575 - val_mae: 6.5234 - learning_rate: 2.0000e-04
# Epoch 11/50
#
# Epoch 11: val_mae improved from 6.52340 to 6.47983, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold4_init.keras
# 318/318 - 111s - 350ms/step - loss: 137.7823 - mae: 8.3137 - val_loss: 95.0208 - val_mae: 6.4798 - learning_rate: 2.0000e-04
# Epoch 12/50
#
# Epoch 12: val_mae improved from 6.47983 to 6.47003, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold4_init.keras
# 318/318 - 111s - 350ms/step - loss: 137.8279 - mae: 8.2773 - val_loss: 94.8571 - val_mae: 6.4700 - learning_rate: 2.0000e-04
# Epoch 13/50
#
# Epoch 13: val_mae improved from 6.47003 to 6.46438, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold4_init.keras
# 318/318 - 110s - 346ms/step - loss: 137.2163 - mae: 8.2464 - val_loss: 94.6985 - val_mae: 6.4644 - learning_rate: 2.0000e-04
# Epoch 14/50
#
# Epoch 14: val_mae improved from 6.46438 to 6.46195, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold4_init.keras
# 318/318 - 111s - 350ms/step - loss: 136.7001 - mae: 8.2373 - val_loss: 94.5291 - val_mae: 6.4620 - learning_rate: 2.0000e-04
# Epoch 15/50
#
# Epoch 15: val_mae improved from 6.46195 to 6.45360, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold4_init.keras
# 318/318 - 111s - 350ms/step - loss: 136.5364 - mae: 8.2247 - val_loss: 94.3679 - val_mae: 6.4536 - learning_rate: 2.0000e-04
# Epoch 16/50
#
# Epoch 16: val_mae improved from 6.45360 to 6.44524, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold4_init.keras
# 318/318 - 111s - 350ms/step - loss: 136.0457 - mae: 8.2083 - val_loss: 94.2054 - val_mae: 6.4452 - learning_rate: 2.0000e-04
# Epoch 17/50
#
# Epoch 17: val_mae did not improve from 6.44524
# 318/318 - 110s - 346ms/step - loss: 135.5604 - mae: 8.1934 - val_loss: 94.0424 - val_mae: 6.4453 - learning_rate: 2.0000e-04
# Epoch 18/50
#
# Epoch 18: val_mae improved from 6.44524 to 6.43697, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold4_init.keras
# 318/318 - 113s - 354ms/step - loss: 136.6251 - mae: 8.2225 - val_loss: 93.9047 - val_mae: 6.4370 - learning_rate: 2.0000e-04
# Epoch 19/50
#
# Epoch 19: val_mae did not improve from 6.43697
# 318/318 - 110s - 346ms/step - loss: 135.5811 - mae: 8.1698 - val_loss: 93.7511 - val_mae: 6.4391 - learning_rate: 2.0000e-04
# Epoch 20/50
#
# Epoch 20: val_mae improved from 6.43697 to 6.43322, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold4_init.keras
# 318/318 - 112s - 351ms/step - loss: 135.5218 - mae: 8.1722 - val_loss: 93.6173 - val_mae: 6.4332 - learning_rate: 2.0000e-04
# Epoch 21/50
#
# Epoch 21: val_mae improved from 6.43322 to 6.42480, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold4_init.keras
# 318/318 - 111s - 351ms/step - loss: 135.5428 - mae: 8.1733 - val_loss: 93.4832 - val_mae: 6.4248 - learning_rate: 2.0000e-04
# Epoch 22/50
#
# Epoch 22: val_mae did not improve from 6.42480
# 318/318 - 110s - 346ms/step - loss: 135.1634 - mae: 8.1639 - val_loss: 93.3453 - val_mae: 6.4258 - learning_rate: 2.0000e-04
# Epoch 23/50
#
# Epoch 23: val_mae improved from 6.42480 to 6.41590, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold4_init.keras
# 318/318 - 111s - 349ms/step - loss: 135.3158 - mae: 8.1578 - val_loss: 93.2174 - val_mae: 6.4159 - learning_rate: 2.0000e-04
# Epoch 24/50
#
# Epoch 24: val_mae improved from 6.41590 to 6.41402, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold4_init.keras
# 318/318 - 112s - 351ms/step - loss: 135.1615 - mae: 8.1490 - val_loss: 93.0910 - val_mae: 6.4140 - learning_rate: 2.0000e-04
# Epoch 25/50
#
# Epoch 25: val_mae improved from 6.41402 to 6.41095, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold4_init.keras
# 318/318 - 111s - 350ms/step - loss: 134.8547 - mae: 8.1474 - val_loss: 92.9663 - val_mae: 6.4110 - learning_rate: 2.0000e-04
# Epoch 26/50
#
# Epoch 26: val_mae improved from 6.41095 to 6.40573, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold4_init.keras
# 318/318 - 112s - 352ms/step - loss: 134.4820 - mae: 8.1249 - val_loss: 92.8499 - val_mae: 6.4057 - learning_rate: 2.0000e-04
# Epoch 27/50
#
# Epoch 27: val_mae improved from 6.40573 to 6.39979, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold4_init.keras
# 318/318 - 111s - 351ms/step - loss: 134.9205 - mae: 8.1466 - val_loss: 92.7359 - val_mae: 6.3998 - learning_rate: 2.0000e-04
# Epoch 28/50
#
# Epoch 28: val_mae improved from 6.39979 to 6.39632, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold4_init.keras
# 318/318 - 111s - 350ms/step - loss: 133.6951 - mae: 8.1168 - val_loss: 92.6230 - val_mae: 6.3963 - learning_rate: 2.0000e-04
# Epoch 29/50
#
# Epoch 29: val_mae improved from 6.39632 to 6.38634, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold4_init.keras
# 318/318 - 111s - 350ms/step - loss: 133.8426 - mae: 8.1165 - val_loss: 92.5106 - val_mae: 6.3863 - learning_rate: 2.0000e-04
# Epoch 30/50
#
# Epoch 30: val_mae did not improve from 6.38634
# 318/318 - 110s - 347ms/step - loss: 133.5141 - mae: 8.1078 - val_loss: 92.3988 - val_mae: 6.3881 - learning_rate: 2.0000e-04
# Epoch 31/50
#
# Epoch 31: val_mae improved from 6.38634 to 6.38407, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold4_init.keras
# 318/318 - 111s - 349ms/step - loss: 134.0008 - mae: 8.1216 - val_loss: 92.2963 - val_mae: 6.3841 - learning_rate: 2.0000e-04
# Epoch 32/50
#
# Epoch 32: val_mae improved from 6.38407 to 6.38323, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold4_init.keras
# 318/318 - 111s - 350ms/step - loss: 133.2478 - mae: 8.0853 - val_loss: 92.1951 - val_mae: 6.3832 - learning_rate: 2.0000e-04
# Epoch 33/50
#
# Epoch 33: val_mae improved from 6.38323 to 6.37617, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold4_init.keras
# 318/318 - 111s - 350ms/step - loss: 133.7066 - mae: 8.0982 - val_loss: 92.1031 - val_mae: 6.3762 - learning_rate: 2.0000e-04
# Epoch 34/50
#
# Epoch 34: val_mae did not improve from 6.37617
# 318/318 - 110s - 346ms/step - loss: 133.9969 - mae: 8.0953 - val_loss: 92.0119 - val_mae: 6.3783 - learning_rate: 2.0000e-04
# Epoch 35/50
#
# Epoch 35: val_mae improved from 6.37617 to 6.37191, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold4_init.keras
# 318/318 - 112s - 351ms/step - loss: 134.0664 - mae: 8.0920 - val_loss: 91.9227 - val_mae: 6.3719 - learning_rate: 2.0000e-04
# Epoch 36/50
#
# Epoch 36: val_mae did not improve from 6.37191
# 318/318 - 110s - 346ms/step - loss: 132.7268 - mae: 8.0533 - val_loss: 91.8198 - val_mae: 6.3751 - learning_rate: 2.0000e-04
# Epoch 37/50
#
# Epoch 37: val_mae improved from 6.37191 to 6.36444, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold4_init.keras
# 318/318 - 111s - 349ms/step - loss: 132.9045 - mae: 8.0649 - val_loss: 91.7334 - val_mae: 6.3644 - learning_rate: 2.0000e-04
# Epoch 38/50
#
# Epoch 38: val_mae did not improve from 6.36444
# 318/318 - 110s - 346ms/step - loss: 132.5619 - mae: 8.0591 - val_loss: 91.6252 - val_mae: 6.3680 - learning_rate: 2.0000e-04
# Epoch 39/50
#
# Epoch 39: val_mae improved from 6.36444 to 6.35954, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold4_init.keras
# 318/318 - 111s - 350ms/step - loss: 132.4900 - mae: 8.0684 - val_loss: 91.5422 - val_mae: 6.3595 - learning_rate: 2.0000e-04
# Epoch 40/50
#
# Epoch 40: val_mae improved from 6.35954 to 6.35599, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold4_init.keras
# 318/318 - 112s - 351ms/step - loss: 132.7363 - mae: 8.0667 - val_loss: 91.4649 - val_mae: 6.3560 - learning_rate: 2.0000e-04
# Epoch 41/50
#
# Epoch 41: val_mae improved from 6.35599 to 6.35196, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold4_init.keras
# 318/318 - 111s - 350ms/step - loss: 132.9118 - mae: 8.0682 - val_loss: 91.3842 - val_mae: 6.3520 - learning_rate: 2.0000e-04
# Epoch 42/50
#
# Epoch 42: val_mae did not improve from 6.35196
# 318/318 - 110s - 346ms/step - loss: 132.7652 - mae: 8.0618 - val_loss: 91.3020 - val_mae: 6.3536 - learning_rate: 2.0000e-04
# Epoch 43/50
#
# Epoch 43: val_mae did not improve from 6.35196
# 318/318 - 110s - 345ms/step - loss: 132.2751 - mae: 8.0285 - val_loss: 91.2158 - val_mae: 6.3602 - learning_rate: 2.0000e-04
# Epoch 44/50
#
# Epoch 44: val_mae did not improve from 6.35196
# 318/318 - 110s - 346ms/step - loss: 131.9512 - mae: 8.0345 - val_loss: 91.1333 - val_mae: 6.3575 - learning_rate: 2.0000e-04
# Epoch 45/50
#
# Epoch 45: val_mae did not improve from 6.35196
#
# Epoch 45: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 318/318 - 110s - 345ms/step - loss: 131.7105 - mae: 8.0261 - val_loss: 91.0571 - val_mae: 6.3580 - learning_rate: 2.0000e-04
# Epoch 46/50
#
# Epoch 46: val_mae improved from 6.35196 to 6.32841, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold4_init.keras
# 318/318 - 111s - 349ms/step - loss: 130.0737 - mae: 7.9577 - val_loss: 91.0777 - val_mae: 6.3284 - learning_rate: 4.0000e-05
# Epoch 47/50
#
# Epoch 47: val_mae improved from 6.32841 to 6.30647, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold4_init.keras
# 318/318 - 111s - 350ms/step - loss: 129.6251 - mae: 7.9286 - val_loss: 91.1106 - val_mae: 6.3065 - learning_rate: 4.0000e-05
# Epoch 48/50
#
# Epoch 48: val_mae improved from 6.30647 to 6.29387, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold4_init.keras
# 318/318 - 111s - 350ms/step - loss: 129.4924 - mae: 7.8731 - val_loss: 91.1325 - val_mae: 6.2939 - learning_rate: 4.0000e-05
# Epoch 49/50
#
# Epoch 49: val_mae improved from 6.29387 to 6.28532, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold4_init.keras
# 318/318 - 111s - 350ms/step - loss: 128.9137 - mae: 7.8572 - val_loss: 91.1456 - val_mae: 6.2853 - learning_rate: 4.0000e-05
# Epoch 50/50
#
# Epoch 50: val_mae improved from 6.28532 to 6.27792, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold4_init.keras
# 318/318 - 114s - 357ms/step - loss: 129.1477 - mae: 7.8370 - val_loss: 91.1545 - val_mae: 6.2779 - learning_rate: 4.0000e-05
# Restoring model weights from the end of the best epoch: 50.
# 🧹 Clearing memory before fine-tune…
# Epoch 1/10
#
# Epoch 1: val_mae improved from inf to 14.02016, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold4_ft.keras
# 318/318 - 428s - 1s/step - loss: 122.7954 - mae: 7.5287 - val_loss: 294.2108 - val_mae: 14.0202 - learning_rate: 1.0000e-04
# Epoch 2/10
#
# Epoch 2: val_mae improved from 14.02016 to 11.01776, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold4_ft.keras
# 318/318 - 137s - 431ms/step - loss: 108.0917 - mae: 7.2905 - val_loss: 218.1780 - val_mae: 11.0178 - learning_rate: 1.0000e-04
# Epoch 3/10
#
# Epoch 3: val_mae improved from 11.01776 to 9.36477, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold4_ft.keras
# 318/318 - 138s - 434ms/step - loss: 133.3843 - mae: 7.5837 - val_loss: 186.5717 - val_mae: 9.3648 - learning_rate: 1.0000e-04
# Epoch 4/10
#
# Epoch 4: val_mae improved from 9.36477 to 6.46314, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold4_ft.keras
# 318/318 - 138s - 433ms/step - loss: 120.8409 - mae: 7.3411 - val_loss: 112.6246 - val_mae: 6.4631 - learning_rate: 1.0000e-04
# Epoch 5/10
#
# Epoch 5: val_mae did not improve from 6.46314
# 318/318 - 136s - 427ms/step - loss: 127.1049 - mae: 7.8709 - val_loss: 96.6172 - val_mae: 6.6938 - learning_rate: 1.0000e-04
# Epoch 6/10
#
# Epoch 6: val_mae improved from 6.46314 to 6.39695, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold4_ft.keras
# 318/318 - 137s - 431ms/step - loss: 131.1808 - mae: 7.5568 - val_loss: 113.2516 - val_mae: 6.3970 - learning_rate: 1.0000e-04
# Epoch 7/10
#
# Epoch 7: val_mae improved from 6.39695 to 6.34246, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/DenseNet121/DenseNet121_fold4_ft.keras
# 318/318 - 138s - 435ms/step - loss: 128.1170 - mae: 7.4209 - val_loss: 104.0489 - val_mae: 6.3425 - learning_rate: 1.0000e-04
# Epoch 8/10
#
# Epoch 8: val_mae did not improve from 6.34246
# 318/318 - 136s - 427ms/step - loss: 129.9329 - mae: 7.6937 - val_loss: 111.7239 - val_mae: 6.3826 - learning_rate: 1.0000e-04
# Epoch 9/10
#
# Epoch 9: val_mae did not improve from 6.34246
# 318/318 - 135s - 424ms/step - loss: 129.7088 - mae: 7.5180 - val_loss: 116.2996 - val_mae: 6.4340 - learning_rate: 1.0000e-04
# Epoch 10/10
#
# Epoch 10: val_mae did not improve from 6.34246
# 318/318 - 135s - 425ms/step - loss: 123.6983 - mae: 7.6346 - val_loss: 96.0794 - val_mae: 6.8101 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 7.
# MAE: 6.84
# RMSE: 11.32
# R2: -0.08
# MAPE: 26.95
# Within ±2 Years (%): 16.24
# Within ±5 Years (%): 65.99
# Within ±10 Years (%): 87.31
# Max Error: 54.56
# Median Error: 4.36
# Cumulative Error ≤ 5 Years (%): 65.99
# Fold 4: MAE 6.84 │ RMSE 11.32 │ R2 -0.08 │ MAPE 26.95
#
# ══════ CV SUMMARY ══════
# MAE                      : 7.66 ± 0.67
# RMSE                     : 12.15 ± 0.76
# R2                       : -0.08 ± 0.02
# MAPE                     : 30.51 ± 3.88
# Within ±2 Years (%)      : 13.57 ± 3.66
# Within ±5 Years (%)      : 58.19 ± 8.61
# Within ±10 Years (%)     : 84.39 ± 2.73
# Max Error                : 61.94 ± 7.46
# Median Error             : 4.82 ± 0.47
# Cumulative Error ≤ 5 Years (%): 58.19 ± 8.61
#
# ── InceptionV3 Fold 1/5 ──
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/epoch_iterator.py:151: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# Epoch 1: val_mae improved from inf to 19.72162, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/InceptionV3/InceptionV3_fold1_init.keras
# 329/329 - 156s - 474ms/step - loss: 133.8196 - mae: 7.2574 - val_loss: 459.2360 - val_mae: 19.7216 - learning_rate: 1.0000e-03
# Epoch 2/50
#
# Epoch 2: val_mae improved from 19.72162 to 18.65014, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/InceptionV3/InceptionV3_fold1_init.keras
# 329/329 - 108s - 330ms/step - loss: 121.9965 - mae: 7.1755 - val_loss: 414.9482 - val_mae: 18.6501 - learning_rate: 1.0000e-03
# Epoch 3/50
#
# Epoch 3: val_mae improved from 18.65014 to 17.97838, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/InceptionV3/InceptionV3_fold1_init.keras
# 329/329 - 109s - 331ms/step - loss: 117.8300 - mae: 7.1582 - val_loss: 388.8836 - val_mae: 17.9784 - learning_rate: 1.0000e-03
# Epoch 4/50
#
# Epoch 4: val_mae improved from 17.97838 to 17.73514, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/InceptionV3/InceptionV3_fold1_init.keras
# 329/329 - 109s - 331ms/step - loss: 114.4400 - mae: 7.1453 - val_loss: 380.3250 - val_mae: 17.7351 - learning_rate: 1.0000e-03
# Epoch 5/50
#
# ...
# Epoch 25/50
#
# Epoch 25: val_mae improved from 9.43009 to 9.40015, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/InceptionV3/InceptionV3_fold1_init.keras
# 329/329 - 109s - 331ms/step - loss: 113.0540 - mae: 7.4452 - val_loss: 151.1356 - val_mae: 9.4001 - learning_rate: 2.0000e-04
# Epoch 26/50
#
# Epoch 26: val_mae improved from 9.40015 to 9.38203, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/InceptionV3/InceptionV3_fold1_init.keras
# 329/329 - 109s - 331ms/step - loss: 112.1697 - mae: 7.4038 - val_loss: 150.7310 - val_mae: 9.3820 - learning_rate: 2.0000e-04
# Epoch 27/50
#
# Epoch 27: val_mae improved from 9.38203 to 9.35419, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/InceptionV3/InceptionV3_fold1_init.keras
# 329/329 - 109s - 331ms/step - loss: 111.9520 - mae: 7.3903 - val_loss: 150.2112 - val_mae: 9.3542 - learning_rate: 2.0000e-04
# Epoch 28/50
#
# Epoch 28: val_mae improved from 9.35419 to 9.31342, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/InceptionV3/InceptionV3_fold1_init.keras
# 329/329 - 110s - 333ms/step - loss: 112.7929 - mae: 7.4169 - val_loss: 149.6026 - val_mae: 9.3134 - learning_rate: 2.0000e-04
# Epoch 29/50
#
# Epoch 29: val_mae improved from 9.31342 to 9.30120, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/InceptionV3/InceptionV3_fold1_init.keras
# 329/329 - 109s - 331ms/step - loss: 112.7295 - mae: 7.3981 - val_loss: 149.3476 - val_mae: 9.3012 - learning_rate: 2.0000e-04
# Epoch 30/50
#
# Epoch 30: val_mae improved from 9.30120 to 9.25067, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/InceptionV3/InceptionV3_fold1_init.keras
# 329/329 - 109s - 331ms/step - loss: 112.6948 - mae: 7.3774 - val_loss: 148.6793 - val_mae: 9.2507 - learning_rate: 2.0000e-04
# Epoch 31/50
#
# Epoch 31: val_mae improved from 9.25067 to 9.24648, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/InceptionV3/InceptionV3_fold1_init.keras
# 329/329 - 109s - 330ms/step - loss: 112.2323 - mae: 7.3916 - val_loss: 148.5267 - val_mae: 9.2465 - learning_rate: 2.0000e-04
# Epoch 32/50
#
# Epoch 32: val_mae improved from 9.24648 to 9.22185, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/InceptionV3/InceptionV3_fold1_init.keras
# 329/329 - 109s - 331ms/step - loss: 112.0063 - mae: 7.3712 - val_loss: 148.2164 - val_mae: 9.2219 - learning_rate: 2.0000e-04
# Epoch 33/50
#
# Epoch 33: val_mae improved from 9.22185 to 9.21482, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/InceptionV3/InceptionV3_fold1_init.keras
# 329/329 - 109s - 331ms/step - loss: 111.9710 - mae: 7.3608 - val_loss: 148.0774 - val_mae: 9.2148 - learning_rate: 2.0000e-04
# Epoch 34/50
#
# Epoch 34: val_mae improved from 9.21482 to 9.18193, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/InceptionV3/InceptionV3_fold1_init.keras
# 329/329 - 109s - 331ms/step - loss: 111.6585 - mae: 7.3465 - val_loss: 147.6706 - val_mae: 9.1819 - learning_rate: 2.0000e-04
# Epoch 35/50
#
# Epoch 35: val_mae improved from 9.18193 to 9.17288, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/InceptionV3/InceptionV3_fold1_init.keras
# 329/329 - 109s - 332ms/step - loss: 111.3975 - mae: 7.3348 - val_loss: 147.5066 - val_mae: 9.1729 - learning_rate: 2.0000e-04
# Epoch 36/50
#
# Epoch 36: val_mae did not improve from 9.17288
# 329/329 - 107s - 326ms/step - loss: 110.8926 - mae: 7.3298 - val_loss: 147.5523 - val_mae: 9.1815 - learning_rate: 2.0000e-04
# Epoch 37/50
#
# Epoch 37: val_mae improved from 9.17288 to 9.16870, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/InceptionV3/InceptionV3_fold1_init.keras
# 329/329 - 108s - 330ms/step - loss: 112.8163 - mae: 7.3809 - val_loss: 147.4134 - val_mae: 9.1687 - learning_rate: 2.0000e-04
# Epoch 38/50
#
# Epoch 38: val_mae improved from 9.16870 to 9.14590, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/InceptionV3/InceptionV3_fold1_init.keras
# 329/329 - 109s - 331ms/step - loss: 111.3172 - mae: 7.3312 - val_loss: 147.1141 - val_mae: 9.1459 - learning_rate: 2.0000e-04
# Epoch 39/50
#
# Epoch 39: val_mae improved from 9.14590 to 9.14095, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/InceptionV3/InceptionV3_fold1_init.keras
# 329/329 - 109s - 330ms/step - loss: 111.5023 - mae: 7.3403 - val_loss: 147.0181 - val_mae: 9.1410 - learning_rate: 2.0000e-04
# Epoch 40/50
#
# Epoch 40: val_mae improved from 9.14095 to 9.12144, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/InceptionV3/InceptionV3_fold1_init.keras
# 329/329 - 108s - 329ms/step - loss: 110.9162 - mae: 7.2992 - val_loss: 146.7803 - val_mae: 9.1214 - learning_rate: 2.0000e-04
# Epoch 41/50
#
# Epoch 41: val_mae improved from 9.12144 to 9.09518, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/InceptionV3/InceptionV3_fold1_init.keras
# 329/329 - 109s - 331ms/step - loss: 111.4971 - mae: 7.3313 - val_loss: 146.4784 - val_mae: 9.0952 - learning_rate: 2.0000e-04
# Epoch 42/50
#
# Epoch 42: val_mae did not improve from 9.09518
# 329/329 - 108s - 327ms/step - loss: 110.5707 - mae: 7.2893 - val_loss: 146.5776 - val_mae: 9.1103 - learning_rate: 2.0000e-04
# Epoch 43/50
#
# Epoch 43: val_mae did not improve from 9.09518
# 329/329 - 107s - 325ms/step - loss: 111.0000 - mae: 7.3124 - val_loss: 146.7675 - val_mae: 9.1301 - learning_rate: 2.0000e-04
# Epoch 44/50
#
# Epoch 44: val_mae improved from 9.09518 to 9.09500, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/InceptionV3/InceptionV3_fold1_init.keras
# 329/329 - 111s - 337ms/step - loss: 111.3491 - mae: 7.3284 - val_loss: 146.4813 - val_mae: 9.0950 - learning_rate: 2.0000e-04
# Epoch 45/50
#
# Epoch 45: val_mae did not improve from 9.09500
# 329/329 - 107s - 326ms/step - loss: 110.0677 - mae: 7.2796 - val_loss: 146.5523 - val_mae: 9.1057 - learning_rate: 2.0000e-04
# Epoch 46/50
#
# Epoch 46: val_mae did not improve from 9.09500
# 329/329 - 107s - 326ms/step - loss: 110.4565 - mae: 7.2852 - val_loss: 146.5002 - val_mae: 9.1033 - learning_rate: 2.0000e-04
# Epoch 47/50
#
# Epoch 47: val_mae improved from 9.09500 to 9.06806, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/InceptionV3/InceptionV3_fold1_init.keras
# 329/329 - 109s - 330ms/step - loss: 111.0633 - mae: 7.3025 - val_loss: 146.1619 - val_mae: 9.0681 - learning_rate: 2.0000e-04
# Epoch 48/50
#
# Epoch 48: val_mae improved from 9.06806 to 9.05779, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/InceptionV3/InceptionV3_fold1_init.keras
# 329/329 - 109s - 330ms/step - loss: 110.8461 - mae: 7.3194 - val_loss: 146.0918 - val_mae: 9.0578 - learning_rate: 2.0000e-04
# Epoch 49/50
#
# Epoch 49: val_mae did not improve from 9.05779
# 329/329 - 107s - 327ms/step - loss: 110.3058 - mae: 7.2894 - val_loss: 146.1370 - val_mae: 9.0675 - learning_rate: 2.0000e-04
# Epoch 50/50
#
# Epoch 50: val_mae did not improve from 9.05779
# 329/329 - 107s - 326ms/step - loss: 110.6630 - mae: 7.2981 - val_loss: 146.0014 - val_mae: 9.0581 - learning_rate: 2.0000e-04
# Restoring model weights from the end of the best epoch: 48.
# 🧹 Clearing memory before fine-tune…
# Epoch 1/10
#
# Epoch 1: val_mae improved from inf to 16.99002, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/InceptionV3/InceptionV3_fold1_ft.keras
# 329/329 - 266s - 810ms/step - loss: 88.9638 - mae: 5.9627 - val_loss: 333.8865 - val_mae: 16.9900 - learning_rate: 1.0000e-04
# Epoch 2/10
#
# Epoch 2: val_mae improved from 16.99002 to 8.28323, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/InceptionV3/InceptionV3_fold1_ft.keras
# 329/329 - 127s - 385ms/step - loss: 105.1972 - mae: 6.0085 - val_loss: 174.1807 - val_mae: 8.2832 - learning_rate: 1.0000e-04
# Epoch 3/10
#
# Epoch 3: val_mae did not improve from 8.28323
# 329/329 - 129s - 391ms/step - loss: 104.9109 - mae: 6.2829 - val_loss: 279.1750 - val_mae: 15.5318 - learning_rate: 1.0000e-04
# Epoch 4/10
#
# Epoch 4: val_mae did not improve from 8.28323
# 329/329 - 124s - 377ms/step - loss: 89.0645 - mae: 5.6538 - val_loss: 233.1376 - val_mae: 9.3447 - learning_rate: 1.0000e-04
# Epoch 5/10
#
# Epoch 5: val_mae did not improve from 8.28323
# 329/329 - 125s - 378ms/step - loss: 96.2454 - mae: 6.0512 - val_loss: 208.4683 - val_mae: 10.5565 - learning_rate: 1.0000e-04
# Epoch 6/10
#
# Epoch 6: val_mae did not improve from 8.28323
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 329/329 - 124s - 378ms/step - loss: 110.5714 - mae: 6.2667 - val_loss: 317.9461 - val_mae: 12.8173 - learning_rate: 1.0000e-04
# Epoch 7/10
#
# Epoch 7: val_mae did not improve from 8.28323
# 329/329 - 124s - 377ms/step - loss: 119.1369 - mae: 7.4743 - val_loss: 319.2452 - val_mae: 12.7346 - learning_rate: 2.0000e-05
# Epoch 8/10
#
# Epoch 8: val_mae did not improve from 8.28323
# 329/329 - 125s - 379ms/step - loss: 116.9669 - mae: 7.2843 - val_loss: 421.7100 - val_mae: 16.2856 - learning_rate: 2.0000e-05
# Epoch 9/10
#
# Epoch 9: val_mae did not improve from 8.28323
# 329/329 - 125s - 379ms/step - loss: 114.4686 - mae: 7.3392 - val_loss: 276.2334 - val_mae: 10.8101 - learning_rate: 2.0000e-05
# Epoch 10/10
#
# Epoch 10: val_mae did not improve from 8.28323
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# 329/329 - 124s - 377ms/step - loss: 100.1913 - mae: 6.9564 - val_loss: 299.7147 - val_mae: 12.0603 - learning_rate: 2.0000e-05
# Epoch 10: early stopping
# Restoring model weights from the end of the best epoch: 2.
# MAE: 8.85
# RMSE: 13.88
# R2: -0.13
# MAPE: 30.65
# Within ±2 Years (%): 19.41
# Within ±5 Years (%): 45.88
# Within ±10 Years (%): 80.00
# Max Error: 57.32
# Median Error: 5.78
# Cumulative Error ≤ 5 Years (%): 45.88
# Fold 1: MAE 8.85 │ RMSE 13.88 │ R2 -0.13 │ MAPE 30.65
#
# ── InceptionV3 Fold 2/5 ──
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/epoch_iterator.py:151: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# Epoch 1: val_mae improved from inf to 21.29623, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/InceptionV3/InceptionV3_fold2_init.keras
# 311/311 - 135s - 434ms/step - loss: 151.0906 - mae: 7.7056 - val_loss: 539.1796 - val_mae: 21.2962 - learning_rate: 1.0000e-03
# Epoch 2/50
#
# Epoch 2: val_mae improved from 21.29623 to 20.07268, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/InceptionV3/InceptionV3_fold2_init.keras
# 311/311 - 105s - 338ms/step - loss: 135.7429 - mae: 7.6106 - val_loss: 484.6169 - val_mae: 20.0727 - learning_rate: 1.0000e-03
# Epoch 3/50
#
# Epoch 3: val_mae improved from 20.07268 to 19.53250, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/InceptionV3/InceptionV3_fold2_init.keras
# 311/311 - 105s - 338ms/step - loss: 128.0099 - mae: 7.5427 - val_loss: 462.4807 - val_mae: 19.5325 - learning_rate: 1.0000e-03
# Epoch 4/50
#
# Epoch 4: val_mae improved from 19.53250 to 19.07839, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/InceptionV3/InceptionV3_fold2_init.keras
# 311/311 - 105s - 339ms/step - loss: 125.9885 - mae: 7.5817 - val_loss: 443.9157 - val_mae: 19.0784 - learning_rate: 1.0000e-03
# Epoch 5/50
#
# Epoch 5: val_mae improved from 19.07839 to 18.70424, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/InceptionV3/InceptionV3_fold2_init.keras
# 311/311 - 106s - 339ms/step - loss: 124.2031 - mae: 7.5626 - val_loss: 428.4594 - val_mae: 18.7042 - learning_rate: 1.0000e-03
# Epoch 6/50
#
# Epoch 6: val_mae improved from 18.70424 to 18.46854, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/InceptionV3/InceptionV3_fold2_init.keras
# 311/311 - 106s - 339ms/step - loss: 123.4729 - mae: 7.5687 - val_loss: 419.2061 - val_mae: 18.4685 - learning_rate: 1.0000e-03
# Epoch 7/50
#
# Epoch 7: val_mae improved from 18.46854 to 18.23976, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/InceptionV3/InceptionV3_fold2_init.keras
# 311/311 - 106s - 340ms/step - loss: 122.8020 - mae: 7.5600 - val_loss: 410.3737 - val_mae: 18.2398 - learning_rate: 1.0000e-03
# Epoch 8/50
#
# Epoch 8: val_mae improved from 18.23976 to 18.13600, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/InceptionV3/InceptionV3_fold2_init.keras
# 311/311 - 105s - 339ms/step - loss: 120.8885 - mae: 7.5438 - val_loss: 406.3287 - val_mae: 18.1360 - learning_rate: 1.0000e-03
# Epoch 9/50
#
# Epoch 9: val_mae improved from 18.13600 to 17.95225, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/InceptionV3/InceptionV3_fold2_init.keras
# 311/311 - 106s - 340ms/step - loss: 119.9528 - mae: 7.5011 - val_loss: 398.9828 - val_mae: 17.9523 - learning_rate: 1.0000e-03
# Epoch 10/50
#
# Epoch 10: val_mae improved from 17.95225 to 17.83290, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/InceptionV3/InceptionV3_fold2_init.keras
# 311/311 - 106s - 339ms/step - loss: 120.3602 - mae: 7.5103 - val_loss: 394.4861 - val_mae: 17.8329 - learning_rate: 1.0000e-03
# Epoch 11/50
#
# Epoch 11: val_mae improved from 17.83290 to 17.81125, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/InceptionV3/InceptionV3_fold2_init.keras
# 311/311 - 105s - 338ms/step - loss: 119.2135 - mae: 7.4801 - val_loss: 393.8534 - val_mae: 17.8112 - learning_rate: 1.0000e-03
# Epoch 12/50
#
# Epoch 12: val_mae improved from 17.81125 to 17.79748, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/InceptionV3/InceptionV3_fold2_init.keras
# 311/311 - 105s - 339ms/step - loss: 119.8064 - mae: 7.5098 - val_loss: 393.7156 - val_mae: 17.7975 - learning_rate: 1.0000e-03
# Epoch 13/50
#
# Epoch 13: val_mae improved from 17.79748 to 17.70279, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/InceptionV3/InceptionV3_fold2_init.keras
# 311/311 - 106s - 340ms/step - loss: 118.9565 - mae: 7.4897 - val_loss: 390.1192 - val_mae: 17.7028 - learning_rate: 1.0000e-03
# Epoch 14/50
#
# Epoch 14: val_mae improved from 17.70279 to 17.68897, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/InceptionV3/InceptionV3_fold2_init.keras
# 311/311 - 106s - 340ms/step - loss: 118.7022 - mae: 7.4858 - val_loss: 389.7157 - val_mae: 17.6890 - learning_rate: 1.0000e-03
# Epoch 15/50
#
# Epoch 15: val_mae did not improve from 17.68897
# 311/311 - 104s - 334ms/step - loss: 118.0987 - mae: 7.4781 - val_loss: 390.8908 - val_mae: 17.7059 - learning_rate: 1.0000e-03
# Epoch 16/50
#
# Epoch 16: val_mae improved from 17.68897 to 17.60374, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/InceptionV3/InceptionV3_fold2_init.keras
# 311/311 - 106s - 339ms/step - loss: 117.9326 - mae: 7.4802 - val_loss: 386.7337 - val_mae: 17.6037 - learning_rate: 1.0000e-03
# Epoch 17/50
#
# Epoch 17: val_mae improved from 17.60374 to 17.56962, saving model to /content/drive/MyDrive/Expanded_HHD_AgeSplit/CV_STRAT_GROUP/InceptionV3/InceptionV3_fold2_init.keras
# 311/311 - 106s - 340ms/step - loss: 117.2056 - mae: 7.4730 - val_loss: 385.7122 - val_mae: 17.5696 - learning_rate: 1.0000e-03
# Epoch 18/50
#
# Epoch 18: val_mae did not improve from 17.56962
# 311/311 - 104s - 335ms/step - loss: 117.3920 - mae: 7.4815 - val_loss: 390.8259 - val_mae: 17.6921 - learning_rate: 1.0000e-03
# Epoch 19/50
#
# Epoch 19: val_mae did not improve from 17.56962
# 311/311 - 104s - 334ms/step - loss: 116.4261 - mae: 7.4575 - val_loss: 397.3883 - val_mae: 17.8481 - learning_rate: 1.0000e-03
# Epoch 20/50
#
# Epoch 20: val_mae did not improve from 17.56962
# 311/311 - 104s - 333ms/step - loss: 116.6234 - mae: 7.4739 - val_loss: 396.3362 - val_mae: 17.8060 - learning_rate: 1.0000e-03
# Epoch 21/50

# %%
# ========= Minimum-Error Metric across Folds =========
import gc
from sklearn.model_selection import StratifiedGroupKFold

min_error_stats = {}     # {model_name: (mean, std)}

# 1) Re-create the CV splitter exactly as in run_cv
sgkf   = StratifiedGroupKFold(n_splits=5, shuffle=True, random_state=42)
splits = list(sgkf.split(df_full.index,
                         df_full["AgeGroup"],
                         df_full["WriterNumber"]))

print("\n══════ Minimum Absolute Error per Model ══════")
for model_name in models.keys():
    fold_min_errors = []

    for fold, (_, test_idx) in enumerate(splits, start=1):
        # --- load the fine-tuned checkpoint for this fold ---
        ckpt_path = os.path.join(
            DATA_ROOT, "CV_STRAT_GROUP", model_name,
            f"{model_name}_fold{fold}_ft.keras"
        )
        # try to load finetuned model, if not existent, fallback to init trained model
        if not os.path.exists(ckpt_path):
            ckpt_path = os.path.join(
                DATA_ROOT, "CV_STRAT_GROUP", model_name,
                f"{model_name}_fold{fold}_init.keras"
            )
        model = tf.keras.models.load_model(ckpt_path, compile=False)

        # --- prepare this fold’s *test* data ---
        test_df = df_full.iloc[test_idx].reset_index(drop=True)
        test_ds = patch_data_tf_dataset_with_ids_from_df(
            test_df, DATA_ROOT,
            patch_size=(400, 400), step_size=200,
            batch_size=64, augment=False
        )

        # --- run inference & aggregate to image-level ---
        preds = []
        for patches, _, img_ids in test_ds:
            p = model.predict(patches, verbose=0).ravel()
            preds.extend(zip(p, img_ids.numpy()))

        y_pred_img, y_true_img = group_predictions_by_image_id(preds, test_df)

        # --- compute this fold’s *minimum* absolute error ---
        abs_errors = np.abs(np.array(y_pred_img) - np.array(y_true_img))
        fold_min_errors.append(abs_errors.min())

        # --- tidy up memory before next fold ---
        del model, test_ds, preds, y_pred_img, y_true_img, abs_errors
        gc.collect()
        tf.keras.backend.clear_session()
        gc.collect()

    # store & display results for this model
    mean_min = np.mean(fold_min_errors)
    std_min  = np.std(fold_min_errors)
    min_error_stats[model_name] = (mean_min, std_min)
    print(f"{model_name:<15}: {mean_min:.2f} ± {std_min:.2f}")

# min_error_stats now holds the summarised metric if you need it later

# %% [markdown]
# # Evaluation

# %% [markdown]
# ## Methods

# %%
def patch_data_tf_dataset_with_ids(
    data_dir, labels_df, dataset_type, patch_size=(400, 400), step_size=200, batch_size=BATCH_SIZE, augment=False
):
    """
    Creates a TensorFlow dataset with patches and 'File' as ImageID.
    """
    subset_df = labels_df[labels_df['Set'] == dataset_type].reset_index(drop=True)
    dataset = tf.data.Dataset.from_tensor_slices(dict(subset_df))

    # Map the function to process rows
    dataset = dataset.map(
        process_row_with_id,
        num_parallel_calls=tf.data.AUTOTUNE
    )

    # Flatten dataset to yield individual patches
    dataset = dataset.flat_map(
        lambda patches, labels, image_id: tf.data.Dataset.zip(
            (
                tf.data.Dataset.from_tensor_slices(patches),
                tf.data.Dataset.from_tensor_slices(labels),
                tf.data.Dataset.from_tensor_slices(image_id) # Keep image_id here
            )
        )
    )

    # Apply augmentation if required
    if augment:
        dataset = dataset.map(
            lambda patch, label, image_id: (tf.image.random_flip_left_right(patch), label, image_id),
            num_parallel_calls=tf.data.AUTOTUNE
        )

    # Batch and prefetch
    dataset = dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)
    return dataset

# %%
def ensemble_predict(models, test_data):
    """
    Makes predictions using an ensemble of models by averaging their outputs.
    Args:
        models (dict): A dictionary of trained models.
        test_data (tf.data.Dataset): Test dataset.
    Returns:
        list: A list of tuples containing predictions and image IDs.
    """
    predictions = []
    for batch in test_data:
        patches, _, image_ids = batch

        batch_preds = [model.predict(patches, verbose=0) for model in models.values()]
        avg_preds = np.mean(batch_preds, axis=0)
        predictions.extend(zip(avg_preds.flatten(), image_ids.numpy()))

    return predictions

# %%
def ensemble_predict_with_weights(models, test_data, weights=None):
    """
    Makes predictions using an ensemble of models by computing a weighted average of their outputs.

    Args:
        models (dict): A dictionary of trained models.
        test_data (tf.data.Dataset): Test dataset.
        weights (dict, optional): A dictionary mapping model names to their weights.
                                  If None, each model is given equal weight.

    Returns:
        list: A list of tuples containing the weighted average predictions and image IDs.
    """
    predictions = []

    # If no weights provided, assign equal weights to all models.
    if weights is None:
        weights = {name: 1.0 for name in models.keys()}

    # Normalize weights so they sum to 1.
    total_weight = sum(weights.values())
    normalized_weights = {name: weight / total_weight for name, weight in weights.items()}

    for batch in test_data:
        patches, _, image_ids = batch

        # Initialize weighted predictions with zeros.
        batch_preds_weighted = np.zeros((patches.shape[0], 1))

        # Accumulate predictions from each model multiplied by its normalized weight.
        for model_name, model in models.items():
            model_weight = normalized_weights.get(model_name, 0)
            preds = model.predict(patches, verbose=0)
            batch_preds_weighted += model_weight * preds

        # Append weighted predictions along with corresponding image IDs.
        predictions.extend(zip(batch_preds_weighted.flatten(), image_ids.numpy()))

    return predictions

# %%
def evaluate_individual_model(model, test_dataset, labels_df):
    """
    Evaluates a single model's performance on a test dataset, grouping predictions by image ID.

    Args:
        model (tf.keras.Model): The trained model to evaluate.
        test_dataset (tf.data.Dataset): Dataset containing test patches, labels, and image IDs.
        labels_df (pd.DataFrame): DataFrame with true labels and file IDs.

    Returns:
        dict: Evaluation metrics including MAE, RMSE, R², MAPE, and thresholds.
    """
    predictions_with_ids = []

    for batch in test_dataset:
        patches, _, image_ids = batch
        predictions = model.predict(patches, verbose=0).flatten()
        predictions_with_ids.extend(zip(predictions, image_ids.numpy()))

    predicted_images, true_images = group_predictions_by_image_id(predictions_with_ids, labels_df)

    return compute_evaluation_metrics(true_images, predicted_images)

# %% [markdown]
# ## Load Models and Test Set

# %%
trained_models = {}
model = 'InceptionV3'

for i in range(1,6):
    model_name = f'{model}_fold{i}'
    trained_models[model_name] = tf.keras.models.load_model(f'/content/drive/MyDrive/HHD_AgeSplit/cross_validation/{model}/{model_name}_finetune.keras')

# %%
# subset your labels to the test rows
test_df = labels_data[labels_data['Set']=='test'].reset_index(drop=True)

test_dataset = patch_data_tf_dataset_with_ids(
    DATA_ROOT,         # root folder
    test_df,           # your subset DataFrame
    dataset_type='test',
    patch_size=(400,400),
    step_size=200,
    batch_size=BATCH_SIZE,
    augment=False
)

# %% [markdown]
# ## Run Evaluations

# %% [markdown]
# ### Ensemble Metrics

# %%
# Generate predictions with image IDs
ensemble_predictions_with_ids = ensemble_predict(trained_models, test_dataset)

# %%
# Group prediction by image
predicted_images, true_images = group_predictions_by_image_id(ensemble_predictions_with_ids, labels_data)

# Compute metrics
evaluation_metrics = compute_evaluation_metrics(true_images, predicted_images)

# %%
import numpy as np
import itertools
from sklearn.metrics import mean_absolute_error

def optimize_ensemble_weights(models, test_dataset, labels_df, search_space, start_index=0):
    """
    Searches over a grid of weight values for each model to find the combination
    that produces the lowest MAE on the given test dataset, starting from a specified index.

    Args:
        models (dict): Dictionary of trained models (keys are model names).
        test_dataset (tf.data.Dataset): Dataset yielding batches of (patches, labels, image_ids).
        labels_df (pd.DataFrame): DataFrame containing true labels with image IDs.
        search_space (dict): Dictionary mapping model names to a tuple (min, max, step) for weight search.
                             Example: {'ResNet50': (0.1, 0.5, 0.1), ...}
        start_index (int): The index of the weight combination from which to resume the grid search.

    Returns:
        tuple: (best_weights, best_mae)
            - best_weights (dict): Weight combination with the lowest MAE.
            - best_mae (float): Corresponding MAE value.
    """
    # Create lists of weight values for each model.
    weight_values = {
        model_name: np.arange(min_val, max_val + search_space[model_name][2], search_space[model_name][2])
        for model_name, (min_val, max_val, _) in search_space.items()
    }

    # Generate all weight combinations.
    all_combinations = list(itertools.product(*[weight_values[m] for m in weight_values]))

    best_weights = None
    best_mae = float('inf')

    total_combinations = len(all_combinations)
    print(f"Starting grid search with {total_combinations} combinations, resuming from index {start_index}.")

    # Resume from the specified start_index.
    for idx, combination in enumerate(all_combinations[start_index:], start=start_index):
        current_weights = dict(zip(weight_values.keys(), combination))
        # Skip combinations where the sum of weights is zero.
        if sum(current_weights.values()) == 0:
            continue

        # Compute ensemble predictions using the current weight combination.
        ensemble_preds_with_ids = ensemble_predict_with_weights(models, test_dataset, current_weights)
        predicted_images, true_images = group_predictions_by_image_id(ensemble_preds_with_ids, labels_df)
        mae = mean_absolute_error(true_images, predicted_images)

        print(f"Combination {idx+1}/{total_combinations} - Weights: {current_weights} => MAE: {mae:.2f}")

        if mae < best_mae:
            best_mae = mae
            best_weights = current_weights.copy()
            print(f"New best found: {best_weights} with MAE: {best_mae:.2f}")

    print(f"Best weights found: {best_weights} with MAE: {best_mae:.2f}")
    return best_weights, best_mae

# Example usage:
search_space = {
    'ResNet50': (0.1, 0.5, 0.1),
    'DenseNet121': (0.1, 0.5, 0.1),
    'InceptionResNetV2': (0.1, 0.5, 0.1)
}

# If your previous run stopped after processing 45 combinations, set start_index=45.
# best_weights, best_mae = optimize_ensemble_weights(trained_models, test_dataset, labels_data, search_space, start_index=85)
# best_weights, best_mae

# %%
# weights = {
#     'ResNet50': 0.8,
#     # 'InceptionV3': 0.15,
#     # 'DenseNet121': 0.33,
#     # 'EfficientNetV2M': 0.1,
#     'InceptionResNetV2': 0.2
# }

# %%
# Generate predictions with image IDs
# ensemble_predictions_with_ids = ensemble_predict_with_weights(trained_models, test_dataset, weights)

# %% [markdown]
# ### Individual Model Metrics

# %%
# Build a dictionary to store each model's predictions (after grouping by image ID)
model_predictions_dict = {}
true_ages = None  # Will be set once from the first model’s predictions

for model_name, model in trained_models.items():
    print(f"\nEvaluating {model_name}...")
    predictions_with_ids = []

    # Iterate over the test dataset and gather predictions with image IDs
    for batch in test_dataset:
        patches, _, image_ids = batch
        preds = model.predict(patches, verbose=0).flatten()
        predictions_with_ids.extend(zip(preds, image_ids.numpy()))

    # Group predictions by image ID (returns (predicted_ages, true_ages))
    model_preds, model_true = group_predictions_by_image_id(predictions_with_ids, labels_data)

    # Store this model's predictions in the dictionary
    model_predictions_dict[model_name] = model_preds

    # Set true_ages once (assuming all models cover the same test set)
    if true_ages is None:
        true_ages = model_true

    # Optionally, compute and display individual evaluation metrics
    _ = compute_evaluation_metrics(model_true, model_preds)
    print("\n\n")

# %% [markdown]
# ### Kappa

# %%
def classify_age(age):
    """
    Classifies a continuous age value into one of four age groups.

    Args:
        age (float): The age value.

    Returns:
        int: Age group number (1 to 4).
            1: Age ≤ 15
            2: 16 ≤ Age ≤ 25
            3: 26 ≤ Age ≤ 50
            4: Age > 50
    """
    if age <= 15:
        return 1
    elif age <= 25:
        return 2
    elif age <= 50:
        return 3
    else:
        return 4

# %%
import numpy as np
import matplotlib.pyplot as plt
import itertools
import warnings
from sklearn.metrics import confusion_matrix, cohen_kappa_score

def analyze_model_agreement(true_ages, model_predictions_dict, plot=True):
    """
    Analyzes agreement between models' age predictions.

    This function:
      1. Converts continuous predictions (and true ages) into categorical age groups
         using your standard `classify_age` function.
      2. Computes a confusion matrix (predicted vs. true categories) for each model.
      3. Computes pairwise Cohen's kappa scores between models to assess how similarly they predict.
      4. Optionally computes Fleiss' kappa for overall multi-model agreement.
      5. Optionally plots:
          - The confusion matrix for each model (with age group labels).
          - A heatmap of pairwise Cohen's kappa scores (with model names).

    Args:
        true_ages (np.ndarray): Array of true continuous ages.
        model_predictions_dict (dict): Dictionary where keys are model names and values are arrays
                                       of predicted continuous ages.
        plot (bool): Whether to generate plots.

    Returns:
        dict: Dictionary containing:
            - 'confusion_matrices': dict mapping each model name to its confusion matrix.
            - 'pairwise_kappa': 2D numpy array of pairwise Cohen's kappa scores.
            - 'model_names': List of model names (order corresponds to pairwise_kappa rows/columns).
            - 'fleiss_kappa': Fleiss' kappa score across all models (if computed, else None).
    """
    # Define the complete set of categorical labels
    labels_categories = [1, 2, 3, 4]

    # Convert true ages into categorical groups using classify_age
    true_categories = np.array([classify_age(age) for age in true_ages])

    # Compute confusion matrices for each model and store each model's categorical predictions.
    confusion_matrices = {}
    model_categories = {}
    for model_name, predictions in model_predictions_dict.items():
        # Convert continuous predictions into age groups using the same binning strategy.
        preds_categories = np.array([classify_age(age) for age in predictions])
        model_categories[model_name] = preds_categories

        # Warn if a model's predictions have only one unique category.
        unique_preds = np.unique(preds_categories)
        if len(unique_preds) == 1:
            print(f"Warning: Model {model_name} produced only one category: {unique_preds}")

        # Suppress warning from confusion_matrix about a single label by using a warnings context.
        with warnings.catch_warnings():
            warnings.filterwarnings("ignore", message="A single label was found in")
            cm = confusion_matrix(true_categories, preds_categories, labels=labels_categories)
        confusion_matrices[model_name] = cm

        if plot:
            # Plot the confusion matrix for the model.
            age_labels = ['<=15', '16-25', '26-50', '>50']
            plt.figure(figsize=(6, 5))
            plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
            plt.title(f'Confusion Matrix - {model_name}')
            plt.colorbar()
            tick_marks = np.arange(len(age_labels))
            plt.xticks(tick_marks, age_labels)
            plt.yticks(tick_marks, age_labels)
            thresh = cm.max() / 2.0 if cm.max() > 0 else 1
            for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
                plt.text(j, i, format(cm[i, j], 'd'),
                         horizontalalignment="center",
                         color="white" if cm[i, j] > thresh else "black")
            plt.ylabel('True Age Groups')
            plt.xlabel('Predicted Age Groups')
            plt.tight_layout()
            plt.show()

    # Compute pairwise Cohen's kappa scores between models (using their categorical predictions).
    model_names = list(model_predictions_dict.keys())
    n_models = len(model_names)
    pairwise_kappa = np.zeros((n_models, n_models))
    for i in range(n_models):
        for j in range(n_models):
            if i == j:
                pairwise_kappa[i, j] = 1.0
            else:
                preds_i = model_categories[model_names[i]]
                preds_j = model_categories[model_names[j]]
                # If either prediction set has less than 2 unique values, assign 0.
                if len(np.unique(preds_i)) < 2 or len(np.unique(preds_j)) < 2:
                    kappa = 0.0
                else:
                    kappa = cohen_kappa_score(preds_i, preds_j, labels=labels_categories)
                    # If kappa is NaN, substitute with 0.
                    if np.isnan(kappa):
                        kappa = 0.0
                pairwise_kappa[i, j] = kappa

    if plot:
        # Plot heatmap of pairwise Cohen's kappa scores.
        plt.figure(figsize=(8, 6))
        plt.imshow(pairwise_kappa, interpolation='nearest', cmap=plt.cm.Blues)
        plt.title("Pairwise Cohen's Kappa Between Models")
        plt.colorbar()
        tick_marks = np.arange(n_models)
        plt.xticks(tick_marks, model_names, rotation=45)
        plt.yticks(tick_marks, model_names)
        for i in range(n_models):
            for j in range(n_models):
                plt.text(j, i, f"{pairwise_kappa[i, j]:.2f}",
                         horizontalalignment="center",
                         color="white" if pairwise_kappa[i, j] > 0.5 else "black")
        plt.tight_layout()
        plt.show()

    # Compute Fleiss' Kappa for multi-model agreement (optional)
    # Prepare a ratings matrix: each row corresponds to a test instance,
    # and each column counts how many models predicted each age group.
    n_samples = len(true_categories)
    n_categories = len(labels_categories)
    ratings = np.zeros((n_samples, n_categories), dtype=int)
    for i in range(n_samples):
        for model_name in model_names:
            rating = model_categories[model_name][i]
            # Adjust index: category 1 -> index 0, etc.
            ratings[i, rating - 1] += 1
    try:
        from statsmodels.stats.inter_rater import fleiss_kappa
        fleiss = fleiss_kappa(ratings, method='fleiss')
    except ImportError:
        print("statsmodels is required for Fleiss' kappa. Skipping this metric.")
        fleiss = None

    results = {
        "confusion_matrices": confusion_matrices,
        "pairwise_kappa": pairwise_kappa,
        "model_names": model_names,
        "fleiss_kappa": fleiss
    }

    return results


# Now that all models have been evaluated, analyze the inter-model agreement
results = analyze_model_agreement(true_ages, model_predictions_dict, plot=True)

# Example output:
print("Pairwise Cohen's Kappa Matrix:")
print(results['pairwise_kappa'])
if results['fleiss_kappa'] is not None:
    print("Fleiss' Kappa (multi-model agreement):", results['fleiss_kappa'])

# %% [markdown]
# ## Save image predictions to csv

# %%
import os, csv
from collections import defaultdict
import tensorflow as tf

# 1️⃣ Configure these:
MODEL_NAMES = ['ResNet50','DenseNet121','InceptionV3','InceptionResNetV2','EfficientNetV2M']


FOLDS       = range(1, 6)
CKPT_ROOT   = '/content/drive/MyDrive/HHD_AgeSplit/cross_validation'
OUT_DIR     = '/content/drive/MyDrive/HHD_AgeSplit/cross_validation/image_level_preds'
os.makedirs(OUT_DIR, exist_ok=True)

# 2️⃣ Your test dataset generator (patch-level):
#    Must yield (patches, labels, image_ids) where image_ids are bytes strings.

# subset your labels to the test rows
test_df = labels_data[labels_data['Set']=='test'].reset_index(drop=True)

test_dataset = patch_data_tf_dataset_with_ids(
    DATA_ROOT,         # root folder
    test_df,           # your subset DataFrame
    dataset_type='test',
    patch_size=(400,400),
    step_size=200,
    batch_size=BATCH_SIZE,
    augment=False
)

for model_name in MODEL_NAMES:
    for fold in FOLDS:
        print(f"\n→ Predicting {model_name} fold {fold}…")

        # — load the finetuned fold checkpoint
        ckpt_path = os.path.join(
            CKPT_ROOT,
            model_name,
            f"{model_name}_fold{fold}_finetune.keras"
        )
        model = tf.keras.models.load_model(ckpt_path)

        # — accumulate patch preds in a dict: { image_id → [pred1, pred2, …] }
        preds_per_image = defaultdict(list)
        for patches, _, image_ids in test_dataset:
            # shape (batch,1) → flatten to (batch,)
            preds = model.predict(patches, verbose=0).ravel()
            for img_id_bytes, p in zip(image_ids.numpy(), preds):
                img_id = img_id_bytes.decode('utf-8')
                preds_per_image[img_id].append(float(p))

        # — write image-level CSV for this fold (mean of its patches)
        csv_path = os.path.join(
            OUT_DIR,
            f"{model_name}_fold{fold}_image_preds.csv"
        )
        with open(csv_path, 'w', newline='') as f:
            writer = csv.writer(f)
            writer.writerow(['Model','Fold','ImageID','Image_Prediction'])
            for img_id, plist in preds_per_image.items():
                mean_pred = sum(plist) / len(plist)
                writer.writerow([model_name, fold, img_id, mean_pred])

        print(f"  ✔️ Saved {csv_path}")

        # — free GPU memory before next model/fold
        tf.keras.backend.clear_session()

# %%
import glob
import pandas as pd

# 1️⃣ Grab all the image-level CSVs
pattern = os.path.join(OUT_DIR, '*_image_preds.csv')
files = glob.glob(pattern)

# 2️⃣ Read & concat
df = pd.concat((pd.read_csv(f) for f in files), ignore_index=True)

# 3️⃣ Ensemble by mean over all (Model,Fold) predictions per image
ensemble_df = (
    df
    .groupby('ImageID', as_index=False)['Image_Prediction']
    .mean()
    .rename(columns={'Image_Prediction':'Ensemble_Prediction'})
)

# 4️⃣ Save
ensemble_csv = os.path.join(OUT_DIR, 'ensemble_image_predictions.csv')
ensemble_df.to_csv(ensemble_csv, index=False)

print(f"✅ Ensemble saved to {ensemble_csv}")

# %%
import os, numpy as np, pandas as pd
from collections import defaultdict

# --- Paths & constants --------------------------------------------------
OUT_DIR      = '/content/drive/MyDrive/HHD_AgeSplit/cross_validation/image_level_preds'
ENSEMBLE_CSV = os.path.join(OUT_DIR, 'ensemble_image_predictions.csv')
MODEL_NAMES = ['ResNet50','DenseNet121','InceptionV3','InceptionResNetV2','EfficientNetV2M']

FOLDS        = range(1, 6)

# --- True labels (image-level) ------------------------------------------
test_df  = labels_data[labels_data['Set'] == 'test'].reset_index(drop=True)
true_df  = test_df[['File', 'Age']].rename(columns={'File': 'ImageID',
                                                    'Age' : 'TrueAge'})

# =========================================================================
# 1) 𝙀𝙉𝙎𝙀𝙈𝘽𝙇𝙀 – all models & folds combined
# =========================================================================
ens_df      = pd.read_csv(ENSEMBLE_CSV)
ens_merged  = ens_df.merge(true_df, on='ImageID')
print("\n📊  Ensemble metrics (all models + folds)")
_ = compute_evaluation_metrics(ens_merged['TrueAge'].values,
                               ens_me   rged['Ensemble_Prediction'].values)

# =========================================================================
# 2) 𝙈𝙊𝘿𝙀𝙇-𝙇𝙀𝙑𝙀𝙇 𝙈𝙀𝙏𝙍𝙄𝘾𝙎 – mean ± std over its folds
# =========================================================================
print("\n──────── Individual models (mean ± std over folds) ────────")
for model_name in MODEL_NAMES:
    fold_mae = []
    preds_per_image = defaultdict(list)   # collect fold preds → model-level avg later

    for fold in FOLDS:
        csv_path = os.path.join(OUT_DIR,
                                f"{model_name}_fold{fold}_image_preds.csv")
        df_fold  = (pd.read_csv(csv_path)
                      .rename(columns={'Image_Prediction': 'Pred'}))
        merged   = df_fold.merge(true_df, on='ImageID')

        # ---- per-fold MAE (quiet) --------------------------------------
        mae = np.mean(np.abs(merged['TrueAge'].values - merged['Pred'].values))
        fold_mae.append(mae)

        # gather predictions for the model-level average
        for img, p in zip(merged['ImageID'], merged['Pred']):
            preds_per_image[img].append(p)

    # ---- model-level predictions: mean over its 5 folds ---------------
    model_avg_preds = {img: np.mean(plist) for img, plist in preds_per_image.items()}
    model_df        = pd.DataFrame(list(model_avg_preds.items()),
                                   columns=['ImageID', 'Model_Pred'])
    merged_model    = model_df.merge(true_df, on='ImageID')

    print(f"\n🔹 {model_name}")
    _ = compute_evaluation_metrics(merged_model['TrueAge'].values,
                                   merged_model['Model_Pred'].values)

    # compact MAE summary
    print(f"   MAE (fold mean ± std): {np.mean(fold_mae):.2f} ± {np.std(fold_mae):.2f}")
